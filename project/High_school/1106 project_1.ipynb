# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_excel('./data/수정_월간_매매가격지수_종합.xlsx',skiprows=2)

# %%
df.head(10)
# Out:
#      지 역  Unnamed: 1  Unnamed: 2  Unnamed: 3 2013년 01월 Unnamed: 5 2013년 04월  \
# 0    NaN         NaN         NaN         NaN        지수        변동률        지수
# 1     전국         NaN         NaN         NaN    92.526      -0.26    92.403
# 2    수도권         NaN         NaN         NaN    91.814      -0.54     91.28
# 3    지방권         NaN         NaN         NaN    93.152       0.01    93.419
# 4  6대광역시         NaN         NaN         NaN    90.586      -0.12    90.641
# 5  5대광역시         NaN         NaN         NaN    89.693       0.05    89.978
# 6    9개도         NaN         NaN         NaN    94.112      -0.25    93.954
# 7    8개도         NaN         NaN         NaN    95.559      -0.03    95.797
# 8     서울         NaN         NaN         NaN    90.656      -0.51    90.344
# 9    종로구         NaN         NaN         NaN    94.265          0    94.352
#
#   Unnamed: 7 2013년 07월 Unnamed: 9  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# ...

# %%
df.drop(columns = ['Unnamed: 1','Unnamed: 2','Unnamed: 3'],axis=1, inplace=True)

# %%
df.head(10)
# Out:
#      지 역 2013년 01월 Unnamed: 5 2013년 04월 Unnamed: 7 2013년 07월 Unnamed: 9  \
# 0    NaN        지수        변동률        지수        변동률        지수        변동률
# 1     전국    92.526      -0.26    92.403       0.12     92.53      -0.07
# 2    수도권    91.814      -0.54     91.28          0    91.052       -0.3
# 3    지방권    93.152       0.01    93.419       0.23    93.885       0.14
# 4  6대광역시    90.586      -0.12    90.641       0.27    91.061       0.12
# 5  5대광역시    89.693       0.05    89.978        0.3    90.558        0.2
# 6    9개도    94.112      -0.25    93.954       0.07    94.133      -0.05
# 7    8개도    95.559      -0.03    95.797       0.17    96.179        0.1
# 8     서울    90.656      -0.51    90.344       0.04    89.878      -0.43
# 9    종로구    94.265          0    94.352       0.12    93.925      -0.15
#
#   2013년 10월 Unnamed: 11 2014년 01월  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# 0        지수         변동률        지수  ...        지수         변동률        지수
# ...

# %%
df.drop([0], inplace=True)

# %%
df.head()
# Out:
#      지 역 2013년 01월 Unnamed: 5 2013년 04월 Unnamed: 7 2013년 07월 Unnamed: 9  \
# 1     전국    92.526      -0.26    92.403       0.12     92.53      -0.07
# 2    수도권    91.814      -0.54     91.28          0    91.052       -0.3
# 3    지방권    93.152       0.01    93.419       0.23    93.885       0.14
# 4  6대광역시    90.586      -0.12    90.641       0.27    91.061       0.12
# 5  5대광역시    89.693       0.05    89.978        0.3    90.558        0.2
#
#   2013년 10월 Unnamed: 11 2014년 01월  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# 1    92.717        0.29    93.268  ...   100.282        0.12   101.133
# 2    91.091        0.33    91.454  ...   103.038        0.27   104.452
# 3    94.215        0.25    94.948  ...    97.847       -0.02    98.212
# 4    91.388         0.3    92.152  ...    100.28        0.17   101.339
# 5    90.926        0.29    91.787  ...   100.176        0.18     101.3
#
#   Unnamed: 61 2020년 04월 Unnamed: 63 2020년 07월 Unnamed: 65 2020년 10월  \
# ...

# %%
df.set_index('지 역',inplace =True)

# %%
df.head()
# Out:
#       2013년 01월 Unnamed: 5 2013년 04월 Unnamed: 7 2013년 07월 Unnamed: 9  \
# 지 역
# 전국       92.526      -0.26    92.403       0.12     92.53      -0.07
# 수도권      91.814      -0.54     91.28          0    91.052       -0.3
# 지방권      93.152       0.01    93.419       0.23    93.885       0.14
# 6대광역시    90.586      -0.12    90.641       0.27    91.061       0.12
# 5대광역시    89.693       0.05    89.978        0.3    90.558        0.2
#
#       2013년 10월 Unnamed: 11 2014년 01월 Unnamed: 13  ... 2019년 10월 Unnamed: 59  \
# 지 역                                                ...
# 전국       92.717        0.29    93.268        0.24  ...   100.282        0.12
# 수도권      91.091        0.33    91.454         0.2  ...   103.038        0.27
# 지방권      94.215        0.25    94.948        0.28  ...    97.847       -0.02
# 6대광역시    91.388         0.3    92.152        0.27  ...    100.28        0.17
# 5대광역시    90.926        0.29    91.787        0.33  ...   100.176        0.18
#
# ...

# %%
len(df.columns)
# Out:
# 64

# %%
df = df.iloc[:, 0::2]

# %%
df.head(20)
# Out:
#       2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월 2014년 07월  \
# 지 역
# 전국       92.526    92.403     92.53    92.717    93.268    93.734    93.804
# 수도권      91.814     91.28    91.052    91.091    91.454    91.934      91.8
# 지방권      93.152    93.419    93.885    94.215    94.948      95.4    95.665
# 6대광역시    90.586    90.641    91.061    91.388    92.152    92.701    92.962
# 5대광역시    89.693    89.978    90.558    90.926    91.787     92.33     92.66
# 9개도      94.112    93.954    94.133     94.34    94.894    95.341    95.403
# 8개도      95.559    95.797    96.179    96.486     97.13    97.521    97.748
# 서울       90.656    90.344    89.878    89.808    90.042    90.444    90.273
# 종로구      94.265    94.352    93.925    93.843    93.905    94.018    93.996
# 중구       92.145        92    91.734     91.59    91.902    92.132    92.303
# 용산구      96.167    95.189    94.307    93.615    93.238    92.857    92.716
# ...

# %%
df_seoul = df.loc['서울':'강동구',:]
df_seoul.head()
# Out:
#     2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월 2014년 07월  \
# 지 역
# 서울     90.656    90.344    89.878    89.808    90.042    90.444    90.273
# 종로구    94.265    94.352    93.925    93.843    93.905    94.018    93.996
# 중구     92.145        92    91.734     91.59    91.902    92.132    92.303
# 용산구    96.167    95.189    94.307    93.615    93.238    92.857    92.716
# 성동구    90.222    88.776    89.173    88.783    89.333    90.093    89.892
#
#     2014년 10월 2015년 01월 2015년 04월  ... 2018년 07월 2018년 10월 2019년 01월  \
# 지 역                                ...
# 서울     90.764     90.93    91.909  ...   104.085   106.588    106.63
# 종로구    94.129    94.176    94.542  ...   103.333   105.223   106.181
# 중구     92.678    93.102    93.926  ...   104.705   107.486   108.351
# 용산구    92.836    92.875    93.166  ...   105.849   109.208   109.652
# 성동구    89.931    89.986    91.151  ...   105.848   108.666   109.255
#
# ...

# %%
from datetime import datetime

# %%
df_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 26 entries, 서울 to 강동구
# Data columns (total 32 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   2013년 01월  26 non-null     object
#  1   2013년 04월  26 non-null     object
#  2   2013년 07월  26 non-null     object
#  3   2013년 10월  26 non-null     object
#  4   2014년 01월  26 non-null     object
#  5   2014년 04월  26 non-null     object
#  6   2014년 07월  26 non-null     object
#  7   2014년 10월  26 non-null     object
#  8   2015년 01월  26 non-null     object
#  9   2015년 04월  26 non-null     object
#  10  2015년 07월  26 non-null     object
#  11  2015년 10월  26 non-null     object
#  12  2016년 01월  26 non-null     object
#  13  2016년 04월  26 non-null     object
#  14  2016년 07월  26 non-null     object
#  15  2016년 10월  26 non-null     object
#  16  2017년 01월  26 non-null     object
#  17  2017년 04월  26 non-null     object
#  18  2017년 07월  26 non-null     object
# ...

# %%
col = df.columns

# %%
from dateutil.parser import parse

# %%
col
# Out:
# "Index(['2013년 01월', '2013년 04월', '2013년 07월', '2013년 10월', '2014년 01월',\n       '2014년 04월', '2014년 07월', '2014년 10월', '2015년 01월', '2015년 04월',\n       '2015년 07월', '2015년 10월', '2016년 01월', '2016년 04월', '2016년 07월',\n       '2016년 10월', '2017년 01월', '2017년 04월', '2017년 07월', '2017년 10월',\n       '2018년 01월', '2018년 04월', '2018년 07월', '2018년 10월', '2019년 01월',\n       '2019년 04월', '2019년 07월', '2019년 10월', '2020년 01월', '2020년 04월',\n       '2020년 07월', '2020년 10월'],\n      dtype='object')"

# %%
li = ['2013년 01월', '2013년 04월', '2013년 07월','2013년 10월','2014년 01월','2014년 04월', '2014년 07월', '2014년 10월', '2015년 01월', '2015년 04월', '2015년 07월', '2015년 10월', '2016년 01월', '2016년 04월', '2016년 07월',  '2016년 10월', '2017년 01월', '2017년 04월', '2017년 07월', '2017년 10월',   '2018년 01월', '2018년 04월', '2018년 07월', '2018년 10월', '2019년 01월',   '2019년 04월', '2019년 07월', '2019년 10월', '2020년 01월', '2020년 04월', '2020년 07월', '2020년 10월']
li
# Out:
# ['2013년 01월',
#  '2013년 04월',
#  '2013년 07월',
#  '2013년 10월',
#  '2014년 01월',
#  '2014년 04월',
#  '2014년 07월',
#  '2014년 10월',
#  '2015년 01월',
#  '2015년 04월',
#  '2015년 07월',
#  '2015년 10월',
#  '2016년 01월',
#  '2016년 04월',
#  '2016년 07월',
#  '2016년 10월',
#  '2017년 01월',
#  '2017년 04월',
#  '2017년 07월',
#  '2017년 10월',
#  '2018년 01월',
#  '2018년 04월',
#  '2018년 07월',
#  '2018년 10월',
#  '2019년 01월',
#  '2019년 04월',
#  '2019년 07월',
#  '2019년 10월',
#  '2020년 01월',
#  '2020년 04월',
#  '2020년 07월',
#  '2020년 10월']

# %%
datetime.strptime('2013년 01월','%Y년 %m월')
# Out:
# datetime.datetime(2013, 1, 1, 0, 0)

# %%
new_c = []
for i in li : 
    ti = datetime.strptime(i,'%Y년 %m월')
    new_c.append(ti)

# %%
new_c
# Out:
# [datetime.datetime(2013, 1, 1, 0, 0),
#  datetime.datetime(2013, 4, 1, 0, 0),
#  datetime.datetime(2013, 7, 1, 0, 0),
#  datetime.datetime(2013, 10, 1, 0, 0),
#  datetime.datetime(2014, 1, 1, 0, 0),
#  datetime.datetime(2014, 4, 1, 0, 0),
#  datetime.datetime(2014, 7, 1, 0, 0),
#  datetime.datetime(2014, 10, 1, 0, 0),
#  datetime.datetime(2015, 1, 1, 0, 0),
#  datetime.datetime(2015, 4, 1, 0, 0),
#  datetime.datetime(2015, 7, 1, 0, 0),
#  datetime.datetime(2015, 10, 1, 0, 0),
#  datetime.datetime(2016, 1, 1, 0, 0),
#  datetime.datetime(2016, 4, 1, 0, 0),
#  datetime.datetime(2016, 7, 1, 0, 0),
#  datetime.datetime(2016, 10, 1, 0, 0),
#  datetime.datetime(2017, 1, 1, 0, 0),
#  datetime.datetime(2017, 4, 1, 0, 0),
#  datetime.datetime(2017, 7, 1, 0, 0),
#  datetime.datetime(2017, 10, 1, 0, 0),
#  datetime.datetime(2018, 1, 1, 0, 0),
#  datetime.datetime(2018, 4, 1, 0, 0),
#  datetime.datetime(2018, 7, 1, 0, 0),
#  datetime.datetime(2018, 10, 1, 0, 0),
# ...
