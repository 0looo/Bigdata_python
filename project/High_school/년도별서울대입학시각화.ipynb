# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm
mpl.rcParams['axes.unicode_minus']= False
path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
uni = pd.read_excel('./data/서울대출신고등학교수정1.xlsx',)
uni.head(1)
# Out:
#    Unnamed: 0      학교명  2020(총합)  2020(정시)  2020(수시)  2019(총합)  2019(정시)  \
# 0           0  외대부고등학교        69        39        30      73.0      36.0
#
#    2019(수시)  2018(총합)  2018(정시)  ...  2014(총합)  2014(정시)  2014(수시)  2013(총합)  \
# 0      37.0        55        24  ...        92      34.0      58.0      45.0
#
#    2013(정시)  2013(수시)         위도          경도                       주소  시,구
# 0      20.0      25.0  37.330141  127.253816  경기도 용인시 처인구 모현면 왕산리 232  용인시
#
# [1 rows x 30 columns]

# %%
uni = uni[['학교명', '2020(총합)', '2019(총합)', '2018(총합)', '2017(총합)','2016(총합)','2015(총합)','2014(총합)','2013(총합)','시,구']]

# %%
uni.head()
# Out:
#        학교명  2020(총합)  2019(총합)  2018(총합)  2017(총합)  2016(총합)  2015(총합)  \
# 0  외대부고등학교        69      73.0        55      74.0        77        61
# 1   하나고등학교        62      51.0        55      54.0        58        54
# 2  대원외고등학교        58      53.0        50      55.0        71        79
# 3   상산고등학교        37      38.0        30      47.0        57        53
# 4  한영외고등학교        28      23.0        34      31.0        28        31
#
#    2014(총합)  2013(총합)  시,구
# 0        92      45.0  용인시
# 1        60      44.0  은평구
# 2        95      83.0  광진구
# 3        53      52.0  전주시
# 4        35      19.0  강동구

# %%
uni.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   학교명       106 non-null    object
#  1   2020(총합)  106 non-null    int64
#  2   2019(총합)  99 non-null     float64
#  3   2018(총합)  106 non-null    int64
#  4   2017(총합)  105 non-null    float64
#  5   2016(총합)  106 non-null    int64
#  6   2015(총합)  106 non-null    int64
#  7   2014(총합)  106 non-null    int64
#  8   2013(총합)  100 non-null    float64
#  9   시,구       106 non-null    object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 8.4+ KB

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2013(총합)')
plt.title('2013')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2014(총합)')
plt.title('2014')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2015(총합)')
plt.title('2015')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2016(총합)')
plt.title('2016')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2017(총합)')
plt.title('2017')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2018(총합)')
plt.title('2018')
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2019(총합)')
plt.title('2019')
plt.show()

# %%
plt.figure(figsize=(50,6))
sns.lineplot(data = uni, x='시,구', y='2020(총합)')
plt.title('2020')
plt.show()

# %%
plt.figure(figsize=(70,6))
uni.plot(kind='bar')

# %%
uni.plot()
plt.xlabel
# Out:
# <function matplotlib.pyplot.xlabel(xlabel, fontdict=None, labelpad=None, **kwargs)>
