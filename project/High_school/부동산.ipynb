# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib as mpl
import matplotlib.font_manager as fm

mpl.rcParams['axes.unicode_minus']= False

path = 'C:/Windows/Fonts/malgun.ttf'
font_name = fm.FontProperties(fname = path, size = 50).get_name()
plt.rc('font', family=font_name)

# %%
df = pd.read_excel('./수정_월간_매매가격지수_종합.xlsx',skiprows=2)

# %%
df.head(10)
# Out:
#      지 역  Unnamed: 1  Unnamed: 2  Unnamed: 3 2013년 01월 Unnamed: 5 2013년 04월  \
# 0    NaN         NaN         NaN         NaN        지수        변동률        지수
# 1     전국         NaN         NaN         NaN    92.526      -0.26    92.403
# 2    수도권         NaN         NaN         NaN    91.814      -0.54     91.28
# 3    지방권         NaN         NaN         NaN    93.152       0.01    93.419
# 4  6대광역시         NaN         NaN         NaN    90.586      -0.12    90.641
# 5  5대광역시         NaN         NaN         NaN    89.693       0.05    89.978
# 6    9개도         NaN         NaN         NaN    94.112      -0.25    93.954
# 7    8개도         NaN         NaN         NaN    95.559      -0.03    95.797
# 8     서울         NaN         NaN         NaN    90.656      -0.51    90.344
# 9    종로구         NaN         NaN         NaN    94.265          0    94.352
#
#   Unnamed: 7 2013년 07월 Unnamed: 9  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# ...

# %%
df.drop(columns = ['Unnamed: 1','Unnamed: 2','Unnamed: 3'],axis=1, inplace=True)

# %%
df.head(10)
# Out:
#      지 역 2013년 01월 Unnamed: 5 2013년 04월 Unnamed: 7 2013년 07월 Unnamed: 9  \
# 0    NaN        지수        변동률        지수        변동률        지수        변동률
# 1     전국    92.526      -0.26    92.403       0.12     92.53      -0.07
# 2    수도권    91.814      -0.54     91.28          0    91.052       -0.3
# 3    지방권    93.152       0.01    93.419       0.23    93.885       0.14
# 4  6대광역시    90.586      -0.12    90.641       0.27    91.061       0.12
# 5  5대광역시    89.693       0.05    89.978        0.3    90.558        0.2
# 6    9개도    94.112      -0.25    93.954       0.07    94.133      -0.05
# 7    8개도    95.559      -0.03    95.797       0.17    96.179        0.1
# 8     서울    90.656      -0.51    90.344       0.04    89.878      -0.43
# 9    종로구    94.265          0    94.352       0.12    93.925      -0.15
#
#   2013년 10월 Unnamed: 11 2014년 01월  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# 0        지수         변동률        지수  ...        지수         변동률        지수
# ...

# %%
df.drop([0], inplace=True)

# %%
df.head()
# Out:
#      지 역 2013년 01월 Unnamed: 5 2013년 04월 Unnamed: 7 2013년 07월 Unnamed: 9  \
# 1     전국    92.526      -0.26    92.403       0.12     92.53      -0.07
# 2    수도권    91.814      -0.54     91.28          0    91.052       -0.3
# 3    지방권    93.152       0.01    93.419       0.23    93.885       0.14
# 4  6대광역시    90.586      -0.12    90.641       0.27    91.061       0.12
# 5  5대광역시    89.693       0.05    89.978        0.3    90.558        0.2
#
#   2013년 10월 Unnamed: 11 2014년 01월  ... 2019년 10월 Unnamed: 59 2020년 01월  \
# 1    92.717        0.29    93.268  ...   100.282        0.12   101.133
# 2    91.091        0.33    91.454  ...   103.038        0.27   104.452
# 3    94.215        0.25    94.948  ...    97.847       -0.02    98.212
# 4    91.388         0.3    92.152  ...    100.28        0.17   101.339
# 5    90.926        0.29    91.787  ...   100.176        0.18     101.3
#
#   Unnamed: 61 2020년 04월 Unnamed: 63 2020년 07월 Unnamed: 65 2020년 10월  \
# ...

# %%
df.set_index('지 역', inplace=True)

# %%
df = df.iloc[:, 0::2]

# %%
df.head(20)
# Out:
#       2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월 2014년 07월  \
# 지 역
# 전국       92.526    92.403     92.53    92.717    93.268    93.734    93.804
# 수도권      91.814     91.28    91.052    91.091    91.454    91.934      91.8
# 지방권      93.152    93.419    93.885    94.215    94.948      95.4    95.665
# 6대광역시    90.586    90.641    91.061    91.388    92.152    92.701    92.962
# 5대광역시    89.693    89.978    90.558    90.926    91.787     92.33     92.66
# 9개도      94.112    93.954    94.133     94.34    94.894    95.341    95.403
# 8개도      95.559    95.797    96.179    96.486     97.13    97.521    97.748
# 서울       90.656    90.344    89.878    89.808    90.042    90.444    90.273
# 종로구      94.265    94.352    93.925    93.843    93.905    94.018    93.996
# 중구       92.145        92    91.734     91.59    91.902    92.132    92.303
# 용산구      96.167    95.189    94.307    93.615    93.238    92.857    92.716
# ...

# %%
df_seoul = df.loc['서울':'강동구',:]
df_seoul.head()
# Out:
#     2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월 2014년 07월  \
# 지 역
# 서울     90.656    90.344    89.878    89.808    90.042    90.444    90.273
# 종로구    94.265    94.352    93.925    93.843    93.905    94.018    93.996
# 중구     92.145        92    91.734     91.59    91.902    92.132    92.303
# 용산구    96.167    95.189    94.307    93.615    93.238    92.857    92.716
# 성동구    90.222    88.776    89.173    88.783    89.333    90.093    89.892
#
#     2014년 10월 2015년 01월 2015년 04월  ... 2018년 07월 2018년 10월 2019년 01월  \
# 지 역                                ...
# 서울     90.764     90.93    91.909  ...   104.085   106.588    106.63
# 종로구    94.129    94.176    94.542  ...   103.333   105.223   106.181
# 중구     92.678    93.102    93.926  ...   104.705   107.486   108.351
# 용산구    92.836    92.875    93.166  ...   105.849   109.208   109.652
# 성동구    89.931    89.986    91.151  ...   105.848   108.666   109.255
#
# ...

# %%
df_seoul = df_seoul.reset_index()
df_seoul.head()
# Out:
#    지 역 2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월 2014년 07월  \
# 0   서울    90.656    90.344    89.878    89.808    90.042    90.444    90.273
# 1  종로구    94.265    94.352    93.925    93.843    93.905    94.018    93.996
# 2   중구    92.145        92    91.734     91.59    91.902    92.132    92.303
# 3  용산구    96.167    95.189    94.307    93.615    93.238    92.857    92.716
# 4  성동구    90.222    88.776    89.173    88.783    89.333    90.093    89.892
#
#   2014년 10월 2015년 01월  ... 2018년 07월 2018년 10월 2019년 01월 2019년 04월 2019년 07월  \
# 0    90.764     90.93  ...   104.085   106.588    106.63   106.011   105.932
# 1    94.129    94.176  ...   103.333   105.223   106.181   106.143   106.144
# 2    92.678    93.102  ...   104.705   107.486   108.351   108.002   107.996
# 3    92.836    92.875  ...   105.849   109.208   109.652   109.343   109.439
# 4    89.931    89.986  ...   105.848   108.666   109.255   108.593       108
#
# ...

# %%
df_seoul = df_seoul.drop([0],axis=0)

# %%
# 최종 df_seoul

# %%
len(df_seoul.columns)
# Out:
# 33

# %%
# df_seoul파일을 연도별로 나누어 평균값 처리

# %%
L =[]
for i in range(0,len(df_seoul.columns),4):
    i = df_seoul.iloc[:,i:i+4]
    L.append(i)
L
# Out:
# [     지 역 2013년 01월 2013년 04월 2013년 07월
#  1    종로구    94.265    94.352    93.925
#  2     중구    92.145        92    91.734
#  3    용산구    96.167    95.189    94.307
#  4    성동구    90.222    88.776    89.173
#  5    광진구     92.92    93.324    91.326
#  6   동대문구    91.502    90.591    90.311
#  7    중랑구    93.484    93.604    93.526
#  8    성북구     94.41    93.465    92.782
#  9    강북구    97.002    96.133    95.765
#  10   도봉구    93.868    92.303    91.436
#  11   노원구    86.768    86.495    86.329
#  12   은평구    94.125    93.087    93.019
#  13  서대문구    93.742    93.268    92.795
#  14   마포구    90.328    89.933    90.063
#  15   양천구    91.338     91.31    90.125
#  16   강서구    90.528     90.06    89.785
#  17   구로구    90.351    90.241    90.007
#  18   금천구    93.665    93.359     92.75
#  19  영등포구    89.634    89.647    88.826
#  20   동작구    88.575    88.576    88.698
#  21   관악구    91.448    91.335    91.318
#  22   서초구     88.64    88.485    87.763
# ...

# %%
L[0].mean().mean()
# Out:
# 90.97741333333333

# %%
dict_1 = {}
for i in range(len(L)):
    meana = L[i].mean().mean()
    dict_1[2013+i] = meana

# %%
dict_1
# Out:
# {2013: 90.97741333333333,
#  2014: 90.73233,
#  2015: 92.10717000000001,
#  2016: 95.2923,
#  2017: 97.60973,
#  2018: 102.03105,
#  2019: 106.35367,
#  2020: 108.49760999999998,
#  2021: 110.65099999999998}

# %%
# 연도별 평균값을 데이터 프레임으로 변환

# %%
from pandas import DataFrame

# %%
seoul_value = DataFrame(dict_1, index=['서울지수'])
seoul_value = seoul_value.T

# %%
seoul_value
# Out:
#             서울지수
# 2013   90.977413
# 2014   90.732330
# 2015   92.107170
# 2016   95.292300
# 2017   97.609730
# 2018  102.031050
# 2019  106.353670
# 2020  108.497610
# 2021  110.651000

# %%
# 연도별 서울의 부동산 지수 그래프

# %%
seoul_value.plot()

# %%
# 서울시 구별 데이터 처리

# %%
# df_seoul_except = df_seoul[df_seoul['지 역']!='서울']
# df_seoul_except
# Out:
#      지 역 2013년 01월 2013년 04월 2013년 07월 2013년 10월 2014년 01월 2014년 04월  \
# 1    종로구    94.265    94.352    93.925    93.843    93.905    94.018
# 2     중구    92.145        92    91.734     91.59    91.902    92.132
# 3    용산구    96.167    95.189    94.307    93.615    93.238    92.857
# 4    성동구    90.222    88.776    89.173    88.783    89.333    90.093
# 5    광진구     92.92    93.324    91.326    89.644    90.673    91.509
# 6   동대문구    91.502    90.591    90.311    89.909     90.29    90.689
# 7    중랑구    93.484    93.604    93.526    94.227    94.413    94.687
# 8    성북구     94.41    93.465    92.782     92.58    92.792    93.054
# 9    강북구    97.002    96.133    95.765    95.353    95.387    95.496
# 10   도봉구    93.868    92.303    91.436    91.394     92.17    92.706
# 11   노원구    86.768    86.495    86.329    85.756    86.121    87.381
# 12   은평구    94.125    93.087    93.019    92.946    92.939    93.204
# 13  서대문구    93.742    93.268    92.795     92.14    92.543    92.711
# ...

# %%
df = df_seoul.T.reset_index()
df
# Out:
#         index        1        2        3        4        5        6        7  \
# 0         지 역      종로구       중구      용산구      성동구      광진구     동대문구      중랑구
# 1   2013년 01월   94.265   92.145   96.167   90.222    92.92   91.502   93.484
# 2   2013년 04월   94.352       92   95.189   88.776   93.324   90.591   93.604
# 3   2013년 07월   93.925   91.734   94.307   89.173   91.326   90.311   93.526
# 4   2013년 10월   93.843    91.59   93.615   88.783   89.644   89.909   94.227
# 5   2014년 01월   93.905   91.902   93.238   89.333   90.673    90.29   94.413
# 6   2014년 04월   94.018   92.132   92.857   90.093   91.509   90.689   94.687
# 7   2014년 07월   93.996   92.303   92.716   89.892   91.182   90.569   94.564
# 8   2014년 10월   94.129   92.678   92.836   89.931   91.331    90.78   94.691
# 9   2015년 01월   94.176   93.102   92.875   89.986   91.619   90.896   94.938
# 10  2015년 04월   94.542   93.926   93.166   91.151   92.783    91.83   95.176
# ...

# %%
df.columns = list(df.loc[0])

# %%
list(df.loc[0])
# Out:
# ['지 역',
#  '종로구',
#  '중구',
#  '용산구',
#  '성동구',
#  '광진구',
#  '동대문구',
#  '중랑구',
#  '성북구',
#  '강북구',
#  '도봉구',
#  '노원구',
#  '은평구',
#  '서대문구',
#  '마포구',
#  '양천구',
#  '강서구',
#  '구로구',
#  '금천구',
#  '영등포구',
#  '동작구',
#  '관악구',
#  '서초구',
#  '강남구',
#  '송파구',
#  '강동구']

# %%
df
# Out:
#           지 역      종로구       중구      용산구      성동구      광진구     동대문구      중랑구  \
# 0         지 역      종로구       중구      용산구      성동구      광진구     동대문구      중랑구
# 1   2013년 01월   94.265   92.145   96.167   90.222    92.92   91.502   93.484
# 2   2013년 04월   94.352       92   95.189   88.776   93.324   90.591   93.604
# 3   2013년 07월   93.925   91.734   94.307   89.173   91.326   90.311   93.526
# 4   2013년 10월   93.843    91.59   93.615   88.783   89.644   89.909   94.227
# 5   2014년 01월   93.905   91.902   93.238   89.333   90.673    90.29   94.413
# 6   2014년 04월   94.018   92.132   92.857   90.093   91.509   90.689   94.687
# 7   2014년 07월   93.996   92.303   92.716   89.892   91.182   90.569   94.564
# 8   2014년 10월   94.129   92.678   92.836   89.931   91.331    90.78   94.691
# 9   2015년 01월   94.176   93.102   92.875   89.986   91.619   90.896   94.938
# 10  2015년 04월   94.542   93.926   93.166   91.151   92.783    91.83   95.176
# ...

# %%
df.drop(0,inplace=True)

# %%
# 지역의 데이터타입 변환

# %%
from datetime import datetime

# %%
df_date = df.loc[:, '지 역'].str.replace('년','').str.replace('월','')
df_date
# Out:
# 1     2013 01
# 2     2013 04
# 3     2013 07
# 4     2013 10
# 5     2014 01
# 6     2014 04
# 7     2014 07
# 8     2014 10
# 9     2015 01
# 10    2015 04
# 11    2015 07
# 12    2015 10
# 13    2016 01
# 14    2016 04
# 15    2016 07
# 16    2016 10
# 17    2017 01
# 18    2017 04
# 19    2017 07
# 20    2017 10
# 21    2018 01
# 22    2018 04
# 23    2018 07
# 24    2018 10
# 25    2019 01
# 26    2019 04
# 27    2019 07
# 28    2019 10
# 29    2020 01
# 30    2020 04
# 31    2020 07
# 32    2020 10
# Name: 지 역, dtype: object

# %%
df_date = pd.to_datetime(df_date)
df_date
# Out:
# 1    2013-01-01
# 2    2013-04-01
# 3    2013-07-01
# 4    2013-10-01
# 5    2014-01-01
# 6    2014-04-01
# 7    2014-07-01
# 8    2014-10-01
# 9    2015-01-01
# 10   2015-04-01
# 11   2015-07-01
# 12   2015-10-01
# 13   2016-01-01
# 14   2016-04-01
# 15   2016-07-01
# 16   2016-10-01
# 17   2017-01-01
# 18   2017-04-01
# 19   2017-07-01
# 20   2017-10-01
# 21   2018-01-01
# 22   2018-04-01
# 23   2018-07-01
# 24   2018-10-01
# 25   2019-01-01
# 26   2019-04-01
# 27   2019-07-01
# 28   2019-10-01
# 29   2020-01-01
# 30   2020-04-01
# 31   2020-07-01
# 32   2020-10-01
# Name: 지 역, dtype: datetime64[ns]

# %%
df['년도'] = df_date

# %%
df[df['년도'].dt.year==2013.0]
# Out:
#          지 역     종로구      중구     용산구     성동구     광진구    동대문구     중랑구     성북구  \
# 1  2013년 01월  94.265  92.145  96.167  90.222   92.92  91.502  93.484   94.41
# 2  2013년 04월  94.352      92  95.189  88.776  93.324  90.591  93.604  93.465
# 3  2013년 07월  93.925  91.734  94.307  89.173  91.326  90.311  93.526  92.782
# 4  2013년 10월  93.843   91.59  93.615  88.783  89.644  89.909  94.227   92.58
#
#       강북구  ...     구로구     금천구    영등포구     동작구     관악구     서초구     강남구  \
# 1  97.002  ...  90.351  93.665  89.634  88.575  91.448   88.64  82.802
# 2  96.133  ...  90.241  93.359  89.647  88.576  91.335  88.485  83.156
# 3  95.765  ...  90.007   92.75  88.826  88.698  91.318  87.763  82.833
# 4  95.353  ...  90.083  92.752  88.705  89.136  91.836  87.495  83.099
#
#       송파구     강동구         년도
# 1   89.72  86.659 2013-01-01
# 2  90.038  86.559 2013-04-01
# 3  88.761  86.355 2013-07-01
# 4  89.268  86.728 2013-10-01
#
# [4 rows x 27 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 32
# Data columns (total 27 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   지 역     32 non-null     object
#  1   종로구     32 non-null     object
#  2   중구      32 non-null     object
#  3   용산구     32 non-null     object
#  4   성동구     32 non-null     object
#  5   광진구     32 non-null     object
#  6   동대문구    32 non-null     object
#  7   중랑구     32 non-null     object
#  8   성북구     32 non-null     object
#  9   강북구     32 non-null     object
#  10  도봉구     32 non-null     object
#  11  노원구     32 non-null     object
#  12  은평구     32 non-null     object
#  13  서대문구    32 non-null     object
#  14  마포구     32 non-null     object
#  15  양천구     32 non-null     object
#  16  강서구     32 non-null     object
#  17  구로구     32 non-null     object
#  18  금천구     32 non-null     object
#  19  영등포구    32 non-null     object
#  20  동작구     32 non-null     object
# ...

# %%
df.drop('지 역',axis=1,inplace=True)

# %%
# 숫자들의 데이터타입 변환

# %%
df.iloc[: ,: -1] = df.iloc[: ,:-1].astype(float)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32 entries, 1 to 32
# Data columns (total 26 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   종로구     32 non-null     float64
#  1   중구      32 non-null     float64
#  2   용산구     32 non-null     float64
#  3   성동구     32 non-null     float64
#  4   광진구     32 non-null     float64
#  5   동대문구    32 non-null     float64
#  6   중랑구     32 non-null     float64
#  7   성북구     32 non-null     float64
#  8   강북구     32 non-null     float64
#  9   도봉구     32 non-null     float64
#  10  노원구     32 non-null     float64
#  11  은평구     32 non-null     float64
#  12  서대문구    32 non-null     float64
#  13  마포구     32 non-null     float64
#  14  양천구     32 non-null     float64
#  15  강서구     32 non-null     float64
#  16  구로구     32 non-null     float64
#  17  금천구     32 non-null     float64
#  18  영등포구    32 non-null     float64
#  19  동작구     32 non-null     float64
# ...

# %%
df.set_index('년도')
# Out:
#                 종로구       중구      용산구      성동구      광진구     동대문구      중랑구  \
# 년도
# 2013-01-01   94.265   92.145   96.167   90.222   92.920   91.502   93.484
# 2013-04-01   94.352   92.000   95.189   88.776   93.324   90.591   93.604
# 2013-07-01   93.925   91.734   94.307   89.173   91.326   90.311   93.526
# 2013-10-01   93.843   91.590   93.615   88.783   89.644   89.909   94.227
# 2014-01-01   93.905   91.902   93.238   89.333   90.673   90.290   94.413
# 2014-04-01   94.018   92.132   92.857   90.093   91.509   90.689   94.687
# 2014-07-01   93.996   92.303   92.716   89.892   91.182   90.569   94.564
# 2014-10-01   94.129   92.678   92.836   89.931   91.331   90.780   94.691
# 2015-01-01   94.176   93.102   92.875   89.986   91.619   90.896   94.938
# 2015-04-01   94.542   93.926   93.166   91.151   92.783   91.830   95.176
# 2015-07-01   95.437   94.463   93.833   92.434   93.676   93.249   95.636
# 2015-10-01   95.816   95.260   94.396   94.275   95.239   95.254   96.551
# ...

# %%
df.min()
# Out:
# 종로구                  93.843
# 중구                    91.59
# 용산구                  92.716
# 성동구                  88.776
# 광진구                  89.644
# 동대문구                 89.909
# 중랑구                  93.484
# 성북구                   92.58
# 강북구                  95.251
# 도봉구                  91.394
# 노원구                  85.756
# 은평구                  92.939
# 서대문구                  92.14
# 마포구                  89.933
# 양천구                  89.194
# 강서구                  89.323
# 구로구                  89.171
# 금천구                  92.476
# 영등포구                 88.474
# 동작구                  88.575
# 관악구                  91.318
# 서초구                  87.495
# 강남구                  82.802
# 송파구                  88.761
# 강동구                  86.355
# 년도      2013-01-01 00:00:00
# dtype: object

# %%
# 전처리 완료

# %%
apt = df.values

# %%
p = df.pivot_table(index='년도')
p
# Out:
#                 강남구      강동구      강북구      강서구      관악구      광진구      구로구  \
# 년도
# 2013-01-01   82.802   86.659   97.002   90.528   91.448   92.920   90.351
# 2013-04-01   83.156   86.559   96.133   90.060   91.335   93.324   90.241
# 2013-07-01   82.833   86.355   95.765   89.785   91.318   91.326   90.007
# 2013-10-01   83.099   86.728   95.353   89.974   91.836   89.644   90.083
# 2014-01-01   83.265   86.649   95.387   90.049   92.201   90.673   89.914
# 2014-04-01   84.167   86.856   95.496   89.845   92.491   91.509   89.987
# 2014-07-01   84.190   86.721   95.251   89.499   92.110   91.182   89.171
# 2014-10-01   85.326   88.452   95.320   89.323   92.304   91.331   89.638
# 2015-01-01   85.518   88.394   95.342   89.392   92.344   91.619   90.123
# 2015-04-01   87.537   90.829   95.540   90.184   92.632   92.783   91.056
# 2015-07-01   89.605   92.674   96.047   91.444   93.554   93.676   92.986
# 2015-10-01   91.163   94.171   97.030   92.608   94.454   95.239   94.405
# ...

# %%
plt.figure(figsize=(10,7))
p.plot()

# %%
loc = df.columns

# %%
sns.relplot(data=df, x='년도',y=apt, col=loc, col_wrap=1, kind='line')
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-75-3c3efb144005> in <module>
# ----> 1 sns.relplot(data=df, x='년도',y=apt, col=loc, col_wrap=1, kind='line')
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in relplot(x, y, hue, size, style, data, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#    1653
#    1654     # Use the full dataset to establish how to draw the semantics
# -> 1655     p = plotter(
#    1656         x=x, y=y, hue=hue, size=size, style=style, data=data,
#    1657         palette=palette, hue_order=hue_order, hue_norm=hue_norm,
#
# ...

# %%
df.shape
# Out:
# (32, 26)

# %%
fig = plt.figure(figsize=(15,80))

for i in range(0,26):
    ax = fig.add_subplot(23,2,i+1)
    df.iloc[:,i].plot(ax = ax)
    plt.title(df.columns[i])
#     plt.set_xticklabels(df.index)
