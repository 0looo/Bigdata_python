# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib
import matplotlib.font_manager as fm
fm.get_fontconfig_fonts()
font_location = '/usr/share/fonts/truetype/nanum/NanumGothicCoding.ttf'
# font_location = 'C:/Windows/Fonts/NanumGothic.ttf' # For Windows
fprop = fm.FontProperties(fname=font_location)


plt.rc('font', family='Malgun Gothic')

# %%
pwd
# Out:
# 'E:\\팀프로젝트'

# %%
df2013 = pd.read_csv('./소상공인상업정보_2013-2020/2013.txt',  sep = '\t')
df2013
# Out:
#        기간  자치구                      구분       합계     합계.1       합계.2  \
# 0      기간  자치구                      구분       합계       합계         합계
# 1      기간  자치구                      구분     사업체수     사업체수       종사자수
# 2      기간  자치구                      구분     사업체수    여성대표자          계
# 3    2013  서울시                      합계  785,094  260,341  4,585,090
# 4    2013  서울시              농업 임업 및 어업       18        3        276
# ..    ...  ...                     ...      ...      ...        ...
# 487  2013  강동구       공공행정 국방 및 사회보장 행정       37        5      2,434
# 488  2013  강동구                 교육 서비스업    1,507      817     10,387
# 489  2013  강동구         보건업 및 사회복지 서비스업    1,136      438     13,166
# 490  2013  강동구      예술 스포츠 및 여가관련 서비스업      903      409      2,971
# 491  2013  강동구  협회 및 단체 수리 및 기타 개인서비스업    3,247    1,592      8,571
#
#           합계.3       합계.4    조직형태별    조직형태별.1  ...   조직형태별.4   조직형태별.5  \
# 0           합계         합계       개인         개인  ...  회사이외의 법인  회사이외의 법인
# ...

# %%
df2013 = df2013.loc[1:, '자치구':'합계.2']
df2013
# Out:
#      자치구                      구분       합계     합계.1       합계.2
# 1    자치구                      구분     사업체수     사업체수       종사자수
# 2    자치구                      구분     사업체수    여성대표자          계
# 3    서울시                      합계  785,094  260,341  4,585,090
# 4    서울시              농업 임업 및 어업       18        3        276
# 5    서울시                      광업       22        1        595
# ..   ...                     ...      ...      ...        ...
# 487  강동구       공공행정 국방 및 사회보장 행정       37        5      2,434
# 488  강동구                 교육 서비스업    1,507      817     10,387
# 489  강동구         보건업 및 사회복지 서비스업    1,136      438     13,166
# 490  강동구      예술 스포츠 및 여가관련 서비스업      903      409      2,971
# 491  강동구  협회 및 단체 수리 및 기타 개인서비스업    3,247    1,592      8,571
#
# [491 rows x 5 columns]

# %%
df2013 = df2013.drop('합계.1', axis=1)
df2013
# Out:
#      자치구                      구분       합계       합계.2
# 1    자치구                      구분     사업체수       종사자수
# 2    자치구                      구분     사업체수          계
# 3    서울시                      합계  785,094  4,585,090
# 4    서울시              농업 임업 및 어업       18        276
# 5    서울시                      광업       22        595
# ..   ...                     ...      ...        ...
# 487  강동구       공공행정 국방 및 사회보장 행정       37      2,434
# 488  강동구                 교육 서비스업    1,507     10,387
# 489  강동구         보건업 및 사회복지 서비스업    1,136     13,166
# 490  강동구      예술 스포츠 및 여가관련 서비스업      903      2,971
# 491  강동구  협회 및 단체 수리 및 기타 개인서비스업    3,247      8,571
#
# [491 rows x 4 columns]

# %%
df2013 = df2013.drop([1,2])
df2013
# Out:
#      자치구                      구분       합계       합계.2
# 3    서울시                      합계  785,094  4,585,090
# 4    서울시              농업 임업 및 어업       18        276
# 5    서울시                      광업       22        595
# 6    서울시                     제조업   58,551    272,972
# 7    서울시         전기 가스 증기 및 수도사업      122     10,148
# ..   ...                     ...      ...        ...
# 487  강동구       공공행정 국방 및 사회보장 행정       37      2,434
# 488  강동구                 교육 서비스업    1,507     10,387
# 489  강동구         보건업 및 사회복지 서비스업    1,136     13,166
# 490  강동구      예술 스포츠 및 여가관련 서비스업      903      2,971
# 491  강동구  협회 및 단체 수리 및 기타 개인서비스업    3,247      8,571
#
# [489 rows x 4 columns]

# %%
df2013.columns=['자치구','구분','사업체수','종사자수']
df2013.head(20)
# Out:
#     자치구                      구분     사업체수       종사자수
# 3   서울시                      합계  785,094  4,585,090
# 4   서울시              농업 임업 및 어업       18        276
# 5   서울시                      광업       22        595
# 6   서울시                     제조업   58,551    272,972
# 7   서울시         전기 가스 증기 및 수도사업      122     10,148
# 8   서울시    하수폐기물처리 원료재생 및 환경복원업      448      6,536
# 9   서울시                     건설업   21,027    286,131
# 10  서울시                도매 및 소매업  226,629    826,015
# 11  서울시                     운수업   93,368    256,611
# 12  서울시               숙박 및 음식점업  123,634    443,079
# 13  서울시     출판 영상 방송통신 및 정보서비스업   19,240    314,316
# 14  서울시                금융 및 보험업   10,165    257,803
# 15  서울시              부동산업 및 임대업   34,629    139,538
# 16  서울시         전문 과학 및 기술 서비스업   33,624    399,412
# 17  서울시      사업시설관리 및 사업지원 서비스업   12,495    360,854
# 18  서울시       공공행정 국방 및 사회보장 행정    1,267    133,561
# 19  서울시                 교육 서비스업   32,240    313,846
# ...

# %%
df2013 = df2013[df2013['구분']=='교육 서비스업']

# %%
df2013 = df2013.reset_index()

# %%
df2013.drop('index', axis=1, inplace=True)
df2013
# Out:
#      자치구       구분    사업체수     종사자수
# 0    서울시  교육 서비스업  32,240  313,846
# 1    종로구  교육 서비스업     866   12,325
# 2     중구  교육 서비스업     510    7,644
# 3    용산구  교육 서비스업     509    7,631
# 4    성동구  교육 서비스업     745   10,030
# 5    광진구  교육 서비스업   1,132   12,597
# 6   동대문구  교육 서비스업     925   14,743
# 7    중랑구  교육 서비스업     898    7,620
# 8    성북구  교육 서비스업   1,304   22,343
# 9    강북구  교육 서비스업     701    5,886
# 10   도봉구  교육 서비스업     975    7,358
# 11   노원구  교육 서비스업   1,810   19,966
# 12   은평구  교육 서비스업   1,402    9,994
# 13  서대문구  교육 서비스업   1,023   14,852
# 14   마포구  교육 서비스업   1,400   14,959
# 15   양천구  교육 서비스업   2,215   13,971
# 16   강서구  교육 서비스업   1,547   11,493
# 17   구로구  교육 서비스업   1,096    9,566
# 18   금천구  교육 서비스업     606    5,176
# 19  영등포구  교육 서비스업   1,183    8,507
# 20   동작구  교육 서비스업   1,181   12,443
# 21   관악구  교육 서비스업   1,217   13,967
# 22   서초구  교육 서비스업   2,147   18,102
# 23   강남구  교육 서비스업   3,179   25,131
# 24   송파구  교육 서비스업   2,162   17,155
# 25   강동구  교육 서비스업   1,507   10,387

# %%
df2013['연도'] = 2013

# %%
df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   구분      26 non-null     object
#  2   사업체수    26 non-null     object
#  3   종사자수    26 non-null     object
#  4   연도      26 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.1+ KB

# %%
df2013['사업체수'] = df2013['사업체수'].str.replace(',','')
df2013['종사자수'] = df2013['종사자수'].str.replace(',','')

# %%
df2013.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   구분      26 non-null     object
#  2   사업체수    26 non-null     object
#  3   종사자수    26 non-null     object
#  4   연도      26 non-null     int64
# dtypes: int64(1), object(4)
# memory usage: 1.1+ KB

# %%
pwd
# Out:
# 'E:\\팀프로젝트'

# %%
read_files = []
for i in range(2013, 2019):
    df = pd.read_csv('./소상공인상업정보_2013-2020/{}.txt'.format(i)\
                , sep = '\t')

    df = df.loc[1:, '자치구':'합계.2']

    df = df.drop('합계.1', axis=1)

    df = df.drop([1,2])

    df.columns=['자치구','구분','사업체수','종사자수']

    df = df[df['구분']=='교육 서비스업']

    df = df.reset_index()

    df.drop('index', axis=1, inplace=True)

    df['년도'] = i

    df['사업체수'] = df['사업체수'].str.replace(',','').astype(int)
    df['종사자수'] = df['종사자수'].str.replace(',','').astype(int)
    
    read_files.append(df)

print(read_files)
# Out:
# [     자치구       구분   사업체수    종사자수    년도
# 0    서울시  교육 서비스업  32240  313846  2013
# 1    종로구  교육 서비스업    866   12325  2013
# 2     중구  교육 서비스업    510    7644  2013
# 3    용산구  교육 서비스업    509    7631  2013
# 4    성동구  교육 서비스업    745   10030  2013
# 5    광진구  교육 서비스업   1132   12597  2013
# 6   동대문구  교육 서비스업    925   14743  2013
# 7    중랑구  교육 서비스업    898    7620  2013
# 8    성북구  교육 서비스업   1304   22343  2013
# 9    강북구  교육 서비스업    701    5886  2013
# 10   도봉구  교육 서비스업    975    7358  2013
# 11   노원구  교육 서비스업   1810   19966  2013
# 12   은평구  교육 서비스업   1402    9994  2013
# 13  서대문구  교육 서비스업   1023   14852  2013
# 14   마포구  교육 서비스업   1400   14959  2013
# 15   양천구  교육 서비스업   2215   13971  2013
# 16   강서구  교육 서비스업   1547   11493  2013
# 17   구로구  교육 서비스업   1096    9566  2013
# 18   금천구  교육 서비스업    606    5176  2013
# 19  영등포구  교육 서비스업   1183    8507  2013
# 20   동작구  교육 서비스업   1181   12443  2013
# 21   관악구  교육 서비스업   1217   13967  2013
# 22   서초구  교육 서비스업   2147   18102  2013
# ...

# %%
len(read_files)
# Out:
# 6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   자치구     26 non-null     object
#  1   구분      26 non-null     object
#  2   사업체수    26 non-null     int32
#  3   종사자수    26 non-null     int32
#  4   년도      26 non-null     int64
# dtypes: int32(2), int64(1), object(2)
# memory usage: 960.0+ bytes

# %%
df = pd.concat(read_files)
df
# Out:
#     자치구       구분   사업체수    종사자수    년도
# 0   서울시  교육 서비스업  32240  313846  2013
# 1   종로구  교육 서비스업    866   12325  2013
# 2    중구  교육 서비스업    510    7644  2013
# 3   용산구  교육 서비스업    509    7631  2013
# 4   성동구  교육 서비스업    745   10030  2013
# ..  ...      ...    ...     ...   ...
# 21  관악구  교육 서비스업   1191   16210  2018
# 22  서초구  교육 서비스업   2615   21404  2018
# 23  강남구  교육 서비스업   3838   29182  2018
# 24  송파구  교육 서비스업   2340   18609  2018
# 25  강동구  교육 서비스업   1490   10844  2018
#
# [156 rows x 5 columns]

# %%
df
# Out:
#     자치구       구분   사업체수    종사자수    년도
# 0   서울시  교육 서비스업  32240  313846  2013
# 1   종로구  교육 서비스업    866   12325  2013
# 2    중구  교육 서비스업    510    7644  2013
# 3   용산구  교육 서비스업    509    7631  2013
# 4   성동구  교육 서비스업    745   10030  2013
# ..  ...      ...    ...     ...   ...
# 21  관악구  교육 서비스업   1191   16210  2018
# 22  서초구  교육 서비스업   2615   21404  2018
# 23  강남구  교육 서비스업   3838   29182  2018
# 24  송파구  교육 서비스업   2340   18609  2018
# 25  강동구  교육 서비스업   1490   10844  2018
#
# [156 rows x 5 columns]

# %%
sns.scatterplot(data=df[df.자치구!='서울시'], x = '년도', y='사업체수', hue = '자치구')

# %%
# 지역별 년도에 따른 사업체수

# %%
df1 = df[df.자치구!='서울시'].groupby(['년도','자치구'])['사업체수'].mean().unstack()
df1.plot()

# %%
df1.plot(kind='bar')

# %%
# pivot table로

# %%
p = df[df.자치구!='서울시'].pivot_table(index='자치구', columns='년도', values='사업체수')
p
# Out:
# 년도    2013  2014  2015  2016  2017  2018
# 자치구
# 강남구   3179  3584  3718  3765  3850  3838
# 강동구   1507  1501  1466  1475  1479  1490
# 강북구    701   709   662   685   683   684
# 강서구   1547  1568  1622  1701  1787  1844
# 관악구   1217  1252  1229  1239  1227  1191
# 광진구   1132  1114  1100  1136  1159  1183
# 구로구   1096  1159  1143  1202  1204  1231
# 금천구    606   624   603   651   675   702
# 노원구   1810  1835  1880  1903  1951  1950
# 도봉구    975   958   942   931   960   962
# 동대문구   925   934   945   959   985  1000
# 동작구   1181  1186  1170  1211  1215  1264
# 마포구   1400  1505  1533  1545  1609  1742
# 서대문구  1023  1008  1021  1040  1078  1086
# 서초구   2147  2338  2452  2439  2529  2615
# 성동구    745   760   785   810   886   961
# 성북구   1304  1304  1302  1337  1372  1382
# 송파구   2162  2140  2253  2287  2299  2340
# 양천구   2215  2245  2285  2280  2366  2376
# 영등포구  1183  1277  1281  1253  1251  1260
# 용산구    509   527   541   539   539   550
# 은평구   1402  1433  1415  1405  1430  1469
# ...

# %%
p.plot()

# %%
p.plot(kind='box')

# %%
# seaborn

# %%
df1
# Out:
# 자치구    강남구   강동구  강북구   강서구   관악구   광진구   구로구  금천구   노원구  도봉구  ...  성동구   성북구  \
# 년도                                                             ...
# 2013  3179  1507  701  1547  1217  1132  1096  606  1810  975  ...  745  1304
# 2014  3584  1501  709  1568  1252  1114  1159  624  1835  958  ...  760  1304
# 2015  3718  1466  662  1622  1229  1100  1143  603  1880  942  ...  785  1302
# 2016  3765  1475  685  1701  1239  1136  1202  651  1903  931  ...  810  1337
# 2017  3850  1479  683  1787  1227  1159  1204  675  1951  960  ...  886  1372
# 2018  3838  1490  684  1844  1191  1183  1231  702  1950  962  ...  961  1382
#
# 자치구    송파구   양천구  영등포구  용산구   은평구  종로구   중구  중랑구
# 년도
# 2013  2162  2215  1183  509  1402  866  510  898
# 2014  2140  2245  1277  527  1433  885  516  926
# 2015  2253  2285  1281  541  1415  876  508  880
# 2016  2287  2280  1253  539  1405  880  481  911
# 2017  2299  2366  1251  539  1430  852  454  922
# 2018  2340  2376  1260  550  1469  850  471  936
#
# ...

# %%
plt.figure(figsize=(15,3))
sns.barplot(data=df[df.자치구!='서울시'], x='자치구', y='사업체수')

# %%
#  연도별 사업체 수
sns.catplot(data=df[df.자치구!='서울시'], x='년도', y='사업체수', col='자치구', kind='bar', col_wrap=1
        )

# %%
plt.figure(figsize=(10,10))
sns.lineplot(data=df[df.자치구!='서울시'], x='년도', y='사업체수', hue='자치구')

# %%
ax = sns.relplot(data=df[df.자치구!='서울시'], x='년도', y='사업체수',\
             col='자치구', col_wrap=1, kind='line')
ax.set(xticklabels=[2013, 2014, 2015, 2016, 2017, 2018])

# %%
p
# Out:
# 년도    2013  2014  2015  2016  2017  2018
# 자치구
# 강남구   3179  3584  3718  3765  3850  3838
# 강동구   1507  1501  1466  1475  1479  1490
# 강북구    701   709   662   685   683   684
# 강서구   1547  1568  1622  1701  1787  1844
# 관악구   1217  1252  1229  1239  1227  1191
# 광진구   1132  1114  1100  1136  1159  1183
# 구로구   1096  1159  1143  1202  1204  1231
# 금천구    606   624   603   651   675   702
# 노원구   1810  1835  1880  1903  1951  1950
# 도봉구    975   958   942   931   960   962
# 동대문구   925   934   945   959   985  1000
# 동작구   1181  1186  1170  1211  1215  1264
# 마포구   1400  1505  1533  1545  1609  1742
# 서대문구  1023  1008  1021  1040  1078  1086
# 서초구   2147  2338  2452  2439  2529  2615
# 성동구    745   760   785   810   886   961
# 성북구   1304  1304  1302  1337  1372  1382
# 송파구   2162  2140  2253  2287  2299  2340
# 양천구   2215  2245  2285  2280  2366  2376
# 영등포구  1183  1277  1281  1253  1251  1260
# 용산구    509   527   541   539   539   550
# 은평구   1402  1433  1415  1405  1430  1469
# ...

# %%
plt.figure(figsize=(13,7))
sns.heatmap(p, cmap='Blues', annot=True, fmt='.0f')

# %%
plt.figure(figsize=(15,7))

sns.boxplot(data=df[df.자치구!='서울시'], x='자치구', y='사업체수')
