# %%
#-*- coding: utf-8 -*-

from tensorflow.keras.datasets import mnist
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

#이미지가 저장될 폴더가 없다면 만듭니다.
import os
if not os.path.exists("./gan_images"):
    os.makedirs("./gan_images")

np.random.seed(3)
tf.random.set_seed(3)

#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*7*7, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((7, 7, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))

#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(28,28,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False

#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))
dis_output = discriminator(generator(ginput))
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # MNIST 데이터 불러오기

  (X_train, _), (_, _) = mnist.load_data()  # 앞서 불러온 적 있는 MNIST를 다시 이용합니다. 단, 테스트과정은 필요없고 이미지만 사용할 것이기 때문에 X_train만 불러왔습니다.
  X_train = X_train.reshape(X_train.shape[0], 28, 28, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  # 픽셀값은 0에서 255사이의 값입니다. 이전에 255로 나누어 줄때는 이를 0~1사이의 값으로 바꾸었던 것인데, 여기서는 127.5를 빼준 뒤 127.5로 나누어 줌으로 인해 -1에서 1사이의 값으로 바뀌게 됩니다.
  #X_train.shape, Y_train.shape, X_test.shape, Y_test.shape

  true = np.ones((batch_size, 1))
  fake = np.zeros((batch_size, 1))

  for i in range(epoch):
          # 실제 데이터를 판별자에 입력하는 부분입니다.
          idx = np.random.randint(0, X_train.shape[0], batch_size)
          imgs = X_train[idx]
          d_loss_real = discriminator.train_on_batch(imgs, true)

          #가상 이미지를 판별자에 입력하는 부분입니다.
          noise = np.random.normal(0, 1, (batch_size, 100))
          gen_imgs = generator.predict(noise)
          d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

          #판별자와 생성자의 오차를 계산합니다.
          d_loss = 0.5 * np.add(d_loss_real, d_loss_fake)
          g_loss = gan.train_on_batch(noise, true)

          print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # 이부분은 중간 과정을 이미지로 저장해 주는 부분입니다. 본 장의 주요 내용과 관련이 없어
        # 소스코드만 첨부합니다. 만들어진 이미지들은 gan_images 폴더에 저장됩니다.
          if i % saving_interval == 0:
              #r, c = 5, 5
              noise = np.random.normal(0, 1, (25, 100))
              gen_imgs = generator.predict(noise)

              # Rescale images 0 - 1
              gen_imgs = 0.5 * gen_imgs + 0.5

              fig, axs = plt.subplots(5, 5)
              count = 0
              for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off')
                      count += 1
              fig.savefig("gan_images/gan_mnist_%d.png" % i)

gan_train(4001, 32, 200)  #4000번 반복되고(+1을 해 주는 것에 주의), 배치 사이즈는 32,  200번 마다 결과가 저장되게 하였습니다.
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 28, 28, 1)         865281
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 212865
# =================================================================
# Total params: 1,078,146
# Trainable params: 852,609
# Non-trainable params: 225,537
# _________________________________________________________________
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# epoch:0  d_loss:0.7053  g_loss:0.6912
# epoch:1  d_loss:0.4626  g_loss:0.3284
# epoch:2  d_loss:0.5724  g_loss:0.1036
# epoch:3  d_loss:0.6593  g_loss:0.0859
# epoch:4  d_loss:0.5761  g_loss:0.1688
# epoch:5  d_loss:0.5080  g_loss:0.4277
# epoch:6  d_loss:0.4876  g_loss:0.7039
# epoch:7  d_loss:0.5094  g_loss:0.8745
# epoch:8  d_loss:0.4966  g_loss:0.8995
# epoch:9  d_loss:0.4866  g_loss:0.8642
# epoch:10  d_loss:0.4175  g_loss:0.7782
# epoch:11  d_loss:0.4424  g_loss:0.7925
# epoch:12  d_loss:0.4931  g_loss:0.8575
# epoch:13  d_loss:0.5008  g_loss:0.9010
# epoch:14  d_loss:0.5963  g_loss:0.9286
# epoch:15  d_loss:0.4912  g_loss:1.0290
# epoch:16  d_loss:0.4162  g_loss:1.0201
# epoch:17  d_loss:0.6287  g_loss:0.8007
# epoch:18  d_loss:0.5620  g_loss:0.6606
# epoch:19  d_loss:0.4504  g_loss:0.7093
# epoch:20  d_loss:0.4344  g_loss:0.7265
# epoch:21  d_loss:0.4980  g_loss:0.7647
# epoch:22  d_loss:0.4982  g_loss:0.6327
# epoch:23  d_loss:0.4445  g_loss:0.5811
# epoch:24  d_loss:0.4561  g_loss:0.6366
# epoch:25  d_loss:0.4451  g_loss:0.6702
# epoch:26  d_loss:0.4984  g_loss:0.6978
# epoch:27  d_loss:0.4707  g_loss:0.5862
# epoch:28  d_loss:0.4749  g_loss:0.5137
# epoch:29  d_loss:0.5037  g_loss:0.5189
# epoch:30  d_loss:0.4355  g_loss:0.5967
# epoch:31  d_loss:0.4571  g_loss:0.6645
# epoch:32  d_loss:0.3976  g_loss:0.6046
# epoch:33  d_loss:0.3831  g_loss:0.6759
# epoch:34  d_loss:0.2772  g_loss:0.7228
# epoch:35  d_loss:0.3306  g_loss:0.8952
# epoch:36  d_loss:0.3458  g_loss:0.6488
# epoch:37  d_loss:0.2951  g_loss:0.7890
# epoch:38  d_loss:0.2617  g_loss:0.9597
# epoch:39  d_loss:0.1670  g_loss:1.2843
# epoch:40  d_loss:0.2444  g_loss:1.2949
# epoch:41  d_loss:0.3464  g_loss:0.9953
# epoch:42  d_loss:0.3239  g_loss:0.8045
# epoch:43  d_loss:0.2073  g_loss:0.9019
# epoch:44  d_loss:0.1877  g_loss:1.0773
# epoch:45  d_loss:0.2516  g_loss:1.4048
# epoch:46  d_loss:0.6249  g_loss:0.8892
# epoch:47  d_loss:0.3991  g_loss:1.4843
# epoch:48  d_loss:0.2148  g_loss:2.5318
# epoch:49  d_loss:0.2221  g_loss:2.5180
# epoch:50  d_loss:0.0971  g_loss:1.9480
# epoch:51  d_loss:0.0967  g_loss:2.0755
# epoch:52  d_loss:0.0967  g_loss:2.4920
# epoch:53  d_loss:0.2226  g_loss:2.8510
# epoch:54  d_loss:0.1998  g_loss:4.1255
# epoch:55  d_loss:0.3632  g_loss:2.9296
# epoch:56  d_loss:0.6648  g_loss:1.7482
# epoch:57  d_loss:0.6863  g_loss:2.3075
# epoch:58  d_loss:0.5696  g_loss:3.5843
# epoch:59  d_loss:0.6920  g_loss:2.7314
# epoch:60  d_loss:0.5896  g_loss:2.2602
# epoch:61  d_loss:0.5372  g_loss:2.5598
# epoch:62  d_loss:0.3382  g_loss:3.6108
# epoch:63  d_loss:0.3006  g_loss:3.9320
# epoch:64  d_loss:0.5400  g_loss:2.6844
# epoch:65  d_loss:0.5677  g_loss:2.4502
# epoch:66  d_loss:0.5471  g_loss:2.3363
# epoch:67  d_loss:0.3971  g_loss:3.1706
# epoch:68  d_loss:0.3599  g_loss:3.1128
# epoch:69  d_loss:0.7566  g_loss:2.0683
# epoch:70  d_loss:0.9160  g_loss:0.9207
# epoch:71  d_loss:0.5210  g_loss:1.5227
# epoch:72  d_loss:0.6818  g_loss:1.8289
# epoch:73  d_loss:0.5903  g_loss:1.3489
# epoch:74  d_loss:0.6541  g_loss:1.2246
# epoch:75  d_loss:0.6050  g_loss:1.5874
# epoch:76  d_loss:0.5149  g_loss:1.7531
# epoch:77  d_loss:0.3058  g_loss:2.7686
# epoch:78  d_loss:0.3173  g_loss:2.8521
# epoch:79  d_loss:0.2420  g_loss:3.0413
# epoch:80  d_loss:0.3424  g_loss:2.4281
# epoch:81  d_loss:0.3972  g_loss:2.8861
# epoch:82  d_loss:0.3559  g_loss:3.4499
# epoch:83  d_loss:0.3830  g_loss:3.7831
# epoch:84  d_loss:0.4190  g_loss:3.2338
# epoch:85  d_loss:1.1611  g_loss:2.2100
# epoch:86  d_loss:0.7131  g_loss:2.5185
# epoch:87  d_loss:0.7484  g_loss:3.2592
# epoch:88  d_loss:1.0410  g_loss:2.6427
# epoch:89  d_loss:0.9619  g_loss:1.8217
# epoch:90  d_loss:0.7612  g_loss:1.7137
# epoch:91  d_loss:0.6692  g_loss:2.1361
# epoch:92  d_loss:0.7255  g_loss:1.5552
# epoch:93  d_loss:0.6320  g_loss:1.6891
# epoch:94  d_loss:0.5894  g_loss:1.4831
# epoch:95  d_loss:0.5526  g_loss:1.3750
# epoch:96  d_loss:0.5820  g_loss:1.5842
# epoch:97  d_loss:0.4977  g_loss:1.4754
# epoch:98  d_loss:0.5103  g_loss:1.5711
# epoch:99  d_loss:0.5582  g_loss:1.4464
# epoch:100  d_loss:0.4903  g_loss:1.5083
# epoch:101  d_loss:0.4156  g_loss:1.3155
# epoch:102  d_loss:0.4249  g_loss:1.3220
# epoch:103  d_loss:0.5466  g_loss:1.4066
# epoch:104  d_loss:0.3697  g_loss:1.2865
# epoch:105  d_loss:0.4943  g_loss:1.1426
# epoch:106  d_loss:0.5272  g_loss:1.2857
# epoch:107  d_loss:0.4830  g_loss:1.1556
# epoch:108  d_loss:0.5170  g_loss:1.1529
# epoch:109  d_loss:0.4164  g_loss:1.1657
# epoch:110  d_loss:0.4355  g_loss:1.1724
# epoch:111  d_loss:0.4860  g_loss:1.0391
# epoch:112  d_loss:0.5269  g_loss:1.0475
# epoch:113  d_loss:0.5876  g_loss:0.9846
# epoch:114  d_loss:0.6553  g_loss:1.1104
# epoch:115  d_loss:0.7223  g_loss:0.8888
# epoch:116  d_loss:0.6308  g_loss:0.7670
# epoch:117  d_loss:0.5878  g_loss:0.8089
# epoch:118  d_loss:0.6258  g_loss:0.9856
# epoch:119  d_loss:0.5540  g_loss:1.2334
# epoch:120  d_loss:0.6217  g_loss:1.1746
# epoch:121  d_loss:0.5722  g_loss:1.2724
# epoch:122  d_loss:0.6476  g_loss:1.1516
# epoch:123  d_loss:0.5588  g_loss:1.1513
# epoch:124  d_loss:0.4635  g_loss:1.2593
# epoch:125  d_loss:0.5659  g_loss:1.1817
# epoch:126  d_loss:0.3885  g_loss:1.4741
# epoch:127  d_loss:0.3096  g_loss:1.7354
# epoch:128  d_loss:0.3107  g_loss:1.9624
# epoch:129  d_loss:0.2881  g_loss:1.9704
# epoch:130  d_loss:0.3710  g_loss:1.6328
# epoch:131  d_loss:0.3617  g_loss:1.7987
# epoch:132  d_loss:0.3746  g_loss:1.4667
# epoch:133  d_loss:0.2735  g_loss:2.2570
# epoch:134  d_loss:0.2726  g_loss:2.2627
# epoch:135  d_loss:0.3031  g_loss:2.7586
# epoch:136  d_loss:0.4734  g_loss:2.1881
# epoch:137  d_loss:0.4070  g_loss:2.4719
# epoch:138  d_loss:0.4505  g_loss:1.9585
# epoch:139  d_loss:0.5498  g_loss:2.1341
# epoch:140  d_loss:0.5436  g_loss:2.2045
# epoch:141  d_loss:0.5933  g_loss:2.4071
# epoch:142  d_loss:0.8004  g_loss:1.9462
# epoch:143  d_loss:0.6785  g_loss:2.0322
# epoch:144  d_loss:0.6375  g_loss:1.8035
# epoch:145  d_loss:0.5763  g_loss:1.9879
# epoch:146  d_loss:0.6904  g_loss:1.7309
# epoch:147  d_loss:0.6366  g_loss:2.2241
# epoch:148  d_loss:0.6396  g_loss:1.9619
# epoch:149  d_loss:0.5189  g_loss:1.9201
# epoch:150  d_loss:0.5929  g_loss:1.6445
# epoch:151  d_loss:0.5958  g_loss:1.7907
# epoch:152  d_loss:0.5363  g_loss:1.7440
# epoch:153  d_loss:0.4250  g_loss:1.7375
# epoch:154  d_loss:0.3443  g_loss:1.9689
# epoch:155  d_loss:0.4230  g_loss:1.8582
# epoch:156  d_loss:0.4024  g_loss:2.1972
# epoch:157  d_loss:0.4181  g_loss:2.1970
# epoch:158  d_loss:0.3645  g_loss:1.8574
# epoch:159  d_loss:0.3919  g_loss:1.8373
# epoch:160  d_loss:0.3393  g_loss:2.0100
# epoch:161  d_loss:0.4584  g_loss:1.6842
# epoch:162  d_loss:0.3596  g_loss:1.9375
# epoch:163  d_loss:0.3559  g_loss:2.0016
# epoch:164  d_loss:0.3910  g_loss:1.7900
# epoch:165  d_loss:0.3130  g_loss:1.9278
# epoch:166  d_loss:0.4617  g_loss:1.8259
# epoch:167  d_loss:0.4288  g_loss:1.7536
# epoch:168  d_loss:0.4581  g_loss:1.6353
# epoch:169  d_loss:0.5928  g_loss:1.4927
# epoch:170  d_loss:0.5064  g_loss:1.2379
# epoch:171  d_loss:0.5514  g_loss:1.2117
# epoch:172  d_loss:0.4864  g_loss:1.2858
# epoch:173  d_loss:0.4525  g_loss:1.0369
# epoch:174  d_loss:0.5878  g_loss:1.3942
# epoch:175  d_loss:0.5730  g_loss:1.3284
# epoch:176  d_loss:0.6414  g_loss:1.3347
# epoch:177  d_loss:0.6625  g_loss:1.2351
# epoch:178  d_loss:0.4885  g_loss:1.0703
# epoch:179  d_loss:0.5987  g_loss:1.0512
# epoch:180  d_loss:0.5906  g_loss:0.8583
# epoch:181  d_loss:0.5532  g_loss:0.9648
# epoch:182  d_loss:0.6431  g_loss:1.0830
# epoch:183  d_loss:0.6610  g_loss:1.0656
# epoch:184  d_loss:0.5608  g_loss:0.9212
# epoch:185  d_loss:0.6432  g_loss:1.0591
# epoch:186  d_loss:0.6012  g_loss:1.0083
# epoch:187  d_loss:0.6080  g_loss:1.1411
# epoch:188  d_loss:0.6308  g_loss:1.1329
# epoch:189  d_loss:0.5883  g_loss:1.1111
# epoch:190  d_loss:0.5365  g_loss:1.1466
# epoch:191  d_loss:0.4747  g_loss:1.4481
# epoch:192  d_loss:0.5057  g_loss:1.3732
# epoch:193  d_loss:0.5336  g_loss:1.5900
# epoch:194  d_loss:0.4984  g_loss:1.3626
# epoch:195  d_loss:0.4268  g_loss:1.5855
# epoch:196  d_loss:0.3738  g_loss:1.7831
# epoch:197  d_loss:0.2657  g_loss:2.4778
# epoch:198  d_loss:0.2842  g_loss:2.5779
# epoch:199  d_loss:0.2995  g_loss:2.7307
# epoch:200  d_loss:0.3961  g_loss:2.3838
# epoch:201  d_loss:0.4327  g_loss:1.9498
# epoch:202  d_loss:0.4967  g_loss:1.9416
# epoch:203  d_loss:0.5259  g_loss:2.2406
# epoch:204  d_loss:0.6092  g_loss:3.1331
# epoch:205  d_loss:0.4480  g_loss:3.3440
# epoch:206  d_loss:0.5461  g_loss:2.7719
# epoch:207  d_loss:0.7069  g_loss:2.2316
# epoch:208  d_loss:0.7323  g_loss:1.5731
# epoch:209  d_loss:0.4883  g_loss:1.6477
# epoch:210  d_loss:0.5155  g_loss:1.8821
# epoch:211  d_loss:0.5796  g_loss:1.5028
# epoch:212  d_loss:0.6586  g_loss:1.4383
# epoch:213  d_loss:0.5617  g_loss:1.6908
# epoch:214  d_loss:0.5072  g_loss:1.5740
# epoch:215  d_loss:0.4819  g_loss:1.6728
# epoch:216  d_loss:0.7984  g_loss:1.5723
# epoch:217  d_loss:0.5790  g_loss:1.5479
# epoch:218  d_loss:0.4953  g_loss:1.5647
# epoch:219  d_loss:0.5933  g_loss:1.3161
# epoch:220  d_loss:0.5110  g_loss:1.3516
# epoch:221  d_loss:0.5357  g_loss:1.3362
# epoch:222  d_loss:0.4264  g_loss:1.6168
# epoch:223  d_loss:0.5687  g_loss:1.2992
# epoch:224  d_loss:0.4692  g_loss:1.3026
# epoch:225  d_loss:0.4307  g_loss:1.3340
# epoch:226  d_loss:0.4552  g_loss:1.5143
# epoch:227  d_loss:0.4635  g_loss:1.6154
# epoch:228  d_loss:0.5164  g_loss:1.7501
# epoch:229  d_loss:0.4591  g_loss:1.4524
# epoch:230  d_loss:0.5247  g_loss:1.7367
# epoch:231  d_loss:0.5936  g_loss:1.4490
# epoch:232  d_loss:0.5373  g_loss:1.6003
# epoch:233  d_loss:0.4973  g_loss:1.6071
# epoch:234  d_loss:0.4353  g_loss:1.6053
# epoch:235  d_loss:0.4453  g_loss:1.4287
# epoch:236  d_loss:0.4612  g_loss:1.7761
# epoch:237  d_loss:0.3735  g_loss:1.6597
# epoch:238  d_loss:0.4057  g_loss:1.6517
# epoch:239  d_loss:0.4315  g_loss:1.6682
# epoch:240  d_loss:0.4034  g_loss:1.5346
# epoch:241  d_loss:0.6001  g_loss:1.4469
# epoch:242  d_loss:0.4099  g_loss:1.6325
# epoch:243  d_loss:0.5449  g_loss:1.4941
# epoch:244  d_loss:0.4765  g_loss:1.5715
# epoch:245  d_loss:0.3960  g_loss:1.3723
# epoch:246  d_loss:0.5223  g_loss:1.8929
# epoch:247  d_loss:0.4147  g_loss:1.7335
# epoch:248  d_loss:0.4528  g_loss:2.2234
# epoch:249  d_loss:0.5857  g_loss:2.1369
# epoch:250  d_loss:0.4837  g_loss:1.8411
# epoch:251  d_loss:0.5061  g_loss:1.8454
# epoch:252  d_loss:0.3508  g_loss:2.0501
# epoch:253  d_loss:0.4457  g_loss:1.9386
# epoch:254  d_loss:0.3631  g_loss:2.3855
# epoch:255  d_loss:0.5086  g_loss:2.1458
# epoch:256  d_loss:0.4438  g_loss:2.0335
# epoch:257  d_loss:0.4479  g_loss:2.2347
# epoch:258  d_loss:0.4428  g_loss:2.4081
# epoch:259  d_loss:0.4384  g_loss:2.5623
# epoch:260  d_loss:0.3438  g_loss:2.4418
# epoch:261  d_loss:0.3601  g_loss:2.1111
# epoch:262  d_loss:0.4365  g_loss:2.0193
# epoch:263  d_loss:0.4033  g_loss:2.1819
# epoch:264  d_loss:0.5138  g_loss:2.0496
# epoch:265  d_loss:0.5058  g_loss:2.2233
# epoch:266  d_loss:0.3848  g_loss:2.4742
# epoch:267  d_loss:0.4269  g_loss:2.6961
# epoch:268  d_loss:0.5135  g_loss:1.8422
# epoch:269  d_loss:0.6443  g_loss:1.4148
# epoch:270  d_loss:0.5864  g_loss:1.3457
# epoch:271  d_loss:0.4488  g_loss:1.6371
# epoch:272  d_loss:0.3824  g_loss:2.3322
# epoch:273  d_loss:0.4931  g_loss:2.1412
# epoch:274  d_loss:0.6000  g_loss:2.1496
# epoch:275  d_loss:0.5117  g_loss:1.9454
# epoch:276  d_loss:0.5445  g_loss:1.4498
# epoch:277  d_loss:0.5567  g_loss:1.2269
# epoch:278  d_loss:0.4611  g_loss:1.6235
# epoch:279  d_loss:0.4290  g_loss:2.1058
# epoch:280  d_loss:0.3344  g_loss:2.2309
# epoch:281  d_loss:0.3800  g_loss:2.2217
# epoch:282  d_loss:0.4580  g_loss:2.2308
# epoch:283  d_loss:0.5282  g_loss:2.0637
# epoch:284  d_loss:0.4750  g_loss:1.7443
# epoch:285  d_loss:0.5373  g_loss:1.5130
# epoch:286  d_loss:0.5103  g_loss:1.7376
# epoch:287  d_loss:0.4994  g_loss:1.8655
# epoch:288  d_loss:0.3867  g_loss:2.5957
# epoch:289  d_loss:0.6112  g_loss:1.8871
# epoch:290  d_loss:0.5765  g_loss:1.6043
# epoch:291  d_loss:0.4976  g_loss:1.7783
# epoch:292  d_loss:0.5177  g_loss:1.3312
# epoch:293  d_loss:0.5071  g_loss:1.3117
# epoch:294  d_loss:0.4352  g_loss:1.6217
# epoch:295  d_loss:0.5629  g_loss:1.9593
# epoch:296  d_loss:0.5381  g_loss:1.7055
# epoch:297  d_loss:0.5294  g_loss:1.5730
# epoch:298  d_loss:0.5630  g_loss:1.7501
# epoch:299  d_loss:0.4579  g_loss:1.8263
# epoch:300  d_loss:0.5680  g_loss:1.6938
# epoch:301  d_loss:0.5868  g_loss:1.6347
# epoch:302  d_loss:0.4428  g_loss:1.8068
# epoch:303  d_loss:0.4760  g_loss:1.5930
# epoch:304  d_loss:0.4940  g_loss:1.5902
# epoch:305  d_loss:0.4809  g_loss:1.5494
# epoch:306  d_loss:0.3610  g_loss:1.8405
# epoch:307  d_loss:0.4816  g_loss:2.0219
# epoch:308  d_loss:0.3826  g_loss:2.0091
# epoch:309  d_loss:0.4383  g_loss:1.9309
# epoch:310  d_loss:0.4816  g_loss:1.7281
# epoch:311  d_loss:0.3098  g_loss:2.2946
# epoch:312  d_loss:0.4239  g_loss:1.6103
# epoch:313  d_loss:0.4014  g_loss:2.0969
# epoch:314  d_loss:0.3971  g_loss:2.0147
# epoch:315  d_loss:0.4414  g_loss:2.3319
# epoch:316  d_loss:0.3010  g_loss:2.4262
# epoch:317  d_loss:0.3786  g_loss:2.0442
# epoch:318  d_loss:0.3722  g_loss:2.2421
# epoch:319  d_loss:0.4156  g_loss:2.1699
# epoch:320  d_loss:0.5498  g_loss:1.8875
# epoch:321  d_loss:0.3900  g_loss:1.9924
# epoch:322  d_loss:0.4476  g_loss:1.7496
# epoch:323  d_loss:0.4484  g_loss:2.0708
# epoch:324  d_loss:0.4593  g_loss:1.4445
# epoch:325  d_loss:0.4676  g_loss:1.6362
# epoch:326  d_loss:0.4110  g_loss:1.4713
# epoch:327  d_loss:0.5231  g_loss:1.7043
# epoch:328  d_loss:0.4401  g_loss:2.1492
# epoch:329  d_loss:0.3828  g_loss:2.3564
# epoch:330  d_loss:0.5195  g_loss:2.0805
# epoch:331  d_loss:0.5161  g_loss:1.6435
# epoch:332  d_loss:0.6342  g_loss:1.3346
# epoch:333  d_loss:0.6452  g_loss:1.1030
# epoch:334  d_loss:0.5482  g_loss:1.3508
# epoch:335  d_loss:0.7073  g_loss:1.4549
# epoch:336  d_loss:0.3957  g_loss:1.9725
# epoch:337  d_loss:0.3967  g_loss:2.2532
# epoch:338  d_loss:0.6609  g_loss:1.9325
# epoch:339  d_loss:0.4438  g_loss:1.7012
# epoch:340  d_loss:0.4747  g_loss:1.3323
# epoch:341  d_loss:0.5225  g_loss:1.2590
# epoch:342  d_loss:0.4464  g_loss:1.5396
# epoch:343  d_loss:0.4454  g_loss:1.6795
# epoch:344  d_loss:0.4427  g_loss:1.8808
# epoch:345  d_loss:0.5064  g_loss:2.2579
# epoch:346  d_loss:0.5982  g_loss:2.4469
# epoch:347  d_loss:0.3297  g_loss:2.3552
# epoch:348  d_loss:0.4416  g_loss:2.3597
# epoch:349  d_loss:0.4068  g_loss:2.1464
# epoch:350  d_loss:0.3959  g_loss:2.4503
# epoch:351  d_loss:0.3879  g_loss:2.6061
# epoch:352  d_loss:0.4168  g_loss:2.5988
# epoch:353  d_loss:0.4546  g_loss:2.1606
# epoch:354  d_loss:0.5661  g_loss:2.0511
# epoch:355  d_loss:0.5635  g_loss:1.8758
# epoch:356  d_loss:0.3934  g_loss:2.1481
# epoch:357  d_loss:0.3795  g_loss:2.5098
# epoch:358  d_loss:0.4678  g_loss:2.3924
# epoch:359  d_loss:0.3550  g_loss:2.9272
# epoch:360  d_loss:0.4738  g_loss:2.5054
# epoch:361  d_loss:0.3534  g_loss:2.3275
# epoch:362  d_loss:0.4034  g_loss:2.1670
# epoch:363  d_loss:0.4104  g_loss:2.2101
# epoch:364  d_loss:0.2877  g_loss:1.8772
# epoch:365  d_loss:0.4304  g_loss:2.0442
# epoch:366  d_loss:0.3044  g_loss:2.4320
# epoch:367  d_loss:0.4130  g_loss:2.6845
# epoch:368  d_loss:0.3983  g_loss:2.5189
# epoch:369  d_loss:0.4559  g_loss:2.2468
# epoch:370  d_loss:0.4169  g_loss:2.4722
# epoch:371  d_loss:0.2526  g_loss:1.9913
# epoch:372  d_loss:0.3051  g_loss:2.3390
# epoch:373  d_loss:0.1887  g_loss:2.1232
# epoch:374  d_loss:0.2756  g_loss:2.6641
# epoch:375  d_loss:0.3568  g_loss:2.4047
# epoch:376  d_loss:0.3362  g_loss:2.1716
# epoch:377  d_loss:0.3039  g_loss:2.1786
# epoch:378  d_loss:0.3936  g_loss:1.9019
# epoch:379  d_loss:0.2637  g_loss:2.0588
# epoch:380  d_loss:0.2592  g_loss:2.7199
# epoch:381  d_loss:0.3111  g_loss:2.1859
# epoch:382  d_loss:0.4010  g_loss:2.0461
# epoch:383  d_loss:0.4239  g_loss:1.9140
# epoch:384  d_loss:0.4513  g_loss:1.9449
# epoch:385  d_loss:0.5798  g_loss:2.0571
# epoch:386  d_loss:0.5270  g_loss:1.9213
# epoch:387  d_loss:0.3654  g_loss:2.1213
# epoch:388  d_loss:0.4925  g_loss:2.1090
# epoch:389  d_loss:0.4007  g_loss:2.1416
# epoch:390  d_loss:0.6726  g_loss:1.6691
# epoch:391  d_loss:0.4760  g_loss:1.3880
# epoch:392  d_loss:0.6063  g_loss:1.3475
# epoch:393  d_loss:0.5620  g_loss:1.6099
# epoch:394  d_loss:0.5199  g_loss:1.6541
# epoch:395  d_loss:0.6369  g_loss:1.7780
# epoch:396  d_loss:0.5307  g_loss:1.5419
# epoch:397  d_loss:0.4761  g_loss:1.4663
# epoch:398  d_loss:0.5203  g_loss:1.5059
# epoch:399  d_loss:0.4275  g_loss:1.9071
# epoch:400  d_loss:0.4783  g_loss:1.7150
# epoch:401  d_loss:0.3502  g_loss:1.7484
# epoch:402  d_loss:0.3919  g_loss:1.7196
# epoch:403  d_loss:0.4572  g_loss:1.7808
# epoch:404  d_loss:0.3372  g_loss:2.0579
# epoch:405  d_loss:0.3569  g_loss:1.8059
# epoch:406  d_loss:0.4369  g_loss:1.7756
# epoch:407  d_loss:0.3242  g_loss:2.0621
# epoch:408  d_loss:0.3495  g_loss:1.6215
# epoch:409  d_loss:0.3559  g_loss:2.2568
# epoch:410  d_loss:0.2426  g_loss:1.9558
# epoch:411  d_loss:0.2367  g_loss:2.4690
# epoch:412  d_loss:0.3921  g_loss:1.6781
# epoch:413  d_loss:0.4313  g_loss:1.7788
# epoch:414  d_loss:0.3498  g_loss:1.8193
# epoch:415  d_loss:0.3399  g_loss:1.9863
# epoch:416  d_loss:0.3072  g_loss:2.1385
# epoch:417  d_loss:0.2257  g_loss:2.3650
# epoch:418  d_loss:0.2842  g_loss:2.4392
# epoch:419  d_loss:0.3053  g_loss:2.2952
# epoch:420  d_loss:0.3533  g_loss:1.8571
# epoch:421  d_loss:0.2649  g_loss:2.3190
# epoch:422  d_loss:0.3141  g_loss:2.3204
# epoch:423  d_loss:0.2770  g_loss:2.0727
# epoch:424  d_loss:0.2901  g_loss:2.0020
# epoch:425  d_loss:0.2111  g_loss:2.4078
# epoch:426  d_loss:0.2426  g_loss:2.5537
# epoch:427  d_loss:0.2013  g_loss:3.0182
# epoch:428  d_loss:0.2066  g_loss:2.8418
# epoch:429  d_loss:0.3797  g_loss:2.5612
# epoch:430  d_loss:0.2982  g_loss:2.1488
# epoch:431  d_loss:0.3558  g_loss:2.4445
# epoch:432  d_loss:0.2998  g_loss:2.6566
# epoch:433  d_loss:0.3453  g_loss:2.8948
# epoch:434  d_loss:0.3861  g_loss:2.2330
# epoch:435  d_loss:0.3092  g_loss:2.1451
# epoch:436  d_loss:0.4473  g_loss:2.0988
# epoch:437  d_loss:0.4299  g_loss:2.0900
# epoch:438  d_loss:0.3190  g_loss:1.9468
# epoch:439  d_loss:0.3913  g_loss:2.2739
# epoch:440  d_loss:0.4034  g_loss:2.1920
# epoch:441  d_loss:0.4393  g_loss:1.6578
# epoch:442  d_loss:0.4150  g_loss:2.0427
# epoch:443  d_loss:0.3788  g_loss:2.0621
# epoch:444  d_loss:0.5390  g_loss:1.9605
# epoch:445  d_loss:0.2990  g_loss:2.5175
# epoch:446  d_loss:0.3707  g_loss:2.2068
# epoch:447  d_loss:0.4070  g_loss:1.7524
# epoch:448  d_loss:0.4750  g_loss:1.5517
# epoch:449  d_loss:0.3804  g_loss:1.8784
# epoch:450  d_loss:0.4033  g_loss:2.6474
# epoch:451  d_loss:0.3612  g_loss:3.1789
# epoch:452  d_loss:0.5019  g_loss:2.6840
# epoch:453  d_loss:0.4257  g_loss:2.0175
# epoch:454  d_loss:0.3144  g_loss:1.5530
# epoch:455  d_loss:0.4110  g_loss:1.5967
# epoch:456  d_loss:0.3930  g_loss:1.6400
# epoch:457  d_loss:0.3139  g_loss:1.7555
# epoch:458  d_loss:0.3507  g_loss:2.1662
# epoch:459  d_loss:0.2851  g_loss:2.3897
# epoch:460  d_loss:0.2573  g_loss:2.5469
# epoch:461  d_loss:0.4053  g_loss:1.9420
# epoch:462  d_loss:0.2684  g_loss:1.9364
# epoch:463  d_loss:0.3075  g_loss:1.9734
# epoch:464  d_loss:0.3147  g_loss:2.0786
# epoch:465  d_loss:0.3374  g_loss:2.5177
# epoch:466  d_loss:0.2893  g_loss:2.4413
# epoch:467  d_loss:0.3129  g_loss:2.1615
# epoch:468  d_loss:0.2244  g_loss:1.9541
# epoch:469  d_loss:0.2505  g_loss:2.3126
# epoch:470  d_loss:0.3216  g_loss:1.9526
# epoch:471  d_loss:0.4825  g_loss:1.8936
# epoch:472  d_loss:0.2791  g_loss:1.9330
# epoch:473  d_loss:0.3222  g_loss:2.0844
# epoch:474  d_loss:0.4229  g_loss:2.0092
# epoch:475  d_loss:0.2992  g_loss:2.0588
# epoch:476  d_loss:0.3398  g_loss:2.1777
# epoch:477  d_loss:0.3562  g_loss:1.8692
# epoch:478  d_loss:0.3207  g_loss:2.2497
# epoch:479  d_loss:0.3455  g_loss:2.2910
# epoch:480  d_loss:0.3604  g_loss:2.3962
# epoch:481  d_loss:0.3962  g_loss:1.8962
# epoch:482  d_loss:0.4570  g_loss:1.8936
# epoch:483  d_loss:0.3878  g_loss:1.6529
# epoch:484  d_loss:0.3527  g_loss:1.7094
# epoch:485  d_loss:0.3285  g_loss:2.2445
# epoch:486  d_loss:0.3847  g_loss:2.0597
# epoch:487  d_loss:0.4188  g_loss:2.3385
# epoch:488  d_loss:0.3668  g_loss:2.0994
# epoch:489  d_loss:0.2976  g_loss:2.2059
# epoch:490  d_loss:0.2857  g_loss:2.4638
# epoch:491  d_loss:0.1891  g_loss:2.8535
# epoch:492  d_loss:0.2732  g_loss:2.8640
# epoch:493  d_loss:0.1994  g_loss:2.9947
# epoch:494  d_loss:0.3004  g_loss:3.1967
# epoch:495  d_loss:0.2432  g_loss:2.6394
# epoch:496  d_loss:0.2361  g_loss:2.5795
# epoch:497  d_loss:0.3732  g_loss:1.9261
# epoch:498  d_loss:0.4355  g_loss:2.6552
# epoch:499  d_loss:0.3716  g_loss:1.9664
# epoch:500  d_loss:0.2769  g_loss:2.1230
# epoch:501  d_loss:0.2874  g_loss:2.5360
# epoch:502  d_loss:0.2302  g_loss:2.7591
# epoch:503  d_loss:0.3607  g_loss:2.1549
# epoch:504  d_loss:0.3776  g_loss:1.8060
# epoch:505  d_loss:0.3349  g_loss:2.0280
# epoch:506  d_loss:0.4872  g_loss:2.1389
# epoch:507  d_loss:0.5316  g_loss:1.8994
# epoch:508  d_loss:0.3289  g_loss:2.6467
# epoch:509  d_loss:0.5419  g_loss:2.6125
# epoch:510  d_loss:0.4896  g_loss:2.1880
# epoch:511  d_loss:0.3922  g_loss:1.8347
# epoch:512  d_loss:0.6403  g_loss:2.2744
# epoch:513  d_loss:0.2111  g_loss:3.4555
# epoch:514  d_loss:0.3175  g_loss:3.3427
# epoch:515  d_loss:0.4243  g_loss:2.8906
# epoch:516  d_loss:0.1709  g_loss:2.7616
# epoch:517  d_loss:0.1282  g_loss:3.2073
# epoch:518  d_loss:0.1668  g_loss:3.2895
# epoch:519  d_loss:0.2009  g_loss:2.9873
# epoch:520  d_loss:0.1545  g_loss:3.0278
# epoch:521  d_loss:0.1476  g_loss:2.7488
# epoch:522  d_loss:0.2785  g_loss:2.6683
# epoch:523  d_loss:0.1622  g_loss:3.4485
# epoch:524  d_loss:0.2002  g_loss:3.1682
# epoch:525  d_loss:0.1665  g_loss:3.7768
# epoch:526  d_loss:0.1340  g_loss:2.5401
# epoch:527  d_loss:0.2535  g_loss:2.7574
# epoch:528  d_loss:0.1718  g_loss:2.4969
# epoch:529  d_loss:0.1982  g_loss:2.8313
# epoch:530  d_loss:0.2072  g_loss:2.3926
# epoch:531  d_loss:0.1324  g_loss:3.2798
# epoch:532  d_loss:0.3024  g_loss:2.7270
# epoch:533  d_loss:0.2970  g_loss:2.4840
# epoch:534  d_loss:0.2205  g_loss:2.6356
# epoch:535  d_loss:0.2107  g_loss:2.6140
# epoch:536  d_loss:0.2027  g_loss:2.8801
# epoch:537  d_loss:0.2406  g_loss:3.0031
# epoch:538  d_loss:0.3711  g_loss:2.6923
# epoch:539  d_loss:0.3200  g_loss:2.0084
# epoch:540  d_loss:0.3268  g_loss:1.7311
# epoch:541  d_loss:0.3229  g_loss:2.0300
# epoch:542  d_loss:0.4600  g_loss:2.9933
# epoch:543  d_loss:0.5424  g_loss:2.3938
# epoch:544  d_loss:0.4702  g_loss:2.0542
# epoch:545  d_loss:0.5042  g_loss:2.4595
# epoch:546  d_loss:0.3982  g_loss:1.7834
# epoch:547  d_loss:0.4724  g_loss:2.0747
# epoch:548  d_loss:0.1737  g_loss:2.7794
# epoch:549  d_loss:0.1979  g_loss:3.3636
# epoch:550  d_loss:0.2205  g_loss:3.7511
# epoch:551  d_loss:0.1203  g_loss:3.3926
# epoch:552  d_loss:0.2938  g_loss:2.7605
# epoch:553  d_loss:0.3284  g_loss:2.0788
# epoch:554  d_loss:0.3667  g_loss:2.2203
# epoch:555  d_loss:0.2953  g_loss:2.5279
# epoch:556  d_loss:0.2410  g_loss:3.8785
# epoch:557  d_loss:0.2084  g_loss:4.4497
# epoch:558  d_loss:0.3552  g_loss:3.4829
# epoch:559  d_loss:0.2139  g_loss:3.5879
# epoch:560  d_loss:0.5033  g_loss:2.5657
# epoch:561  d_loss:0.2004  g_loss:1.9592
# epoch:562  d_loss:0.2987  g_loss:2.0311
# epoch:563  d_loss:0.3277  g_loss:2.4302
# epoch:564  d_loss:0.1539  g_loss:3.0469
# epoch:565  d_loss:0.2097  g_loss:2.8859
# epoch:566  d_loss:0.4847  g_loss:2.7074
# epoch:567  d_loss:0.1982  g_loss:2.2684
# epoch:568  d_loss:0.2549  g_loss:2.6124
# epoch:569  d_loss:0.2258  g_loss:2.2337
# epoch:570  d_loss:0.1605  g_loss:2.6422
# epoch:571  d_loss:0.2634  g_loss:2.8004
# epoch:572  d_loss:0.1239  g_loss:2.3998
# epoch:573  d_loss:0.2093  g_loss:2.8032
# epoch:574  d_loss:0.1625  g_loss:2.6278
# epoch:575  d_loss:0.1486  g_loss:3.3719
# epoch:576  d_loss:0.2749  g_loss:2.9545
# epoch:577  d_loss:0.1759  g_loss:3.3738
# epoch:578  d_loss:0.2019  g_loss:3.0046
# epoch:579  d_loss:0.1230  g_loss:3.0256
# epoch:580  d_loss:0.2097  g_loss:2.7508
# epoch:581  d_loss:0.1384  g_loss:3.2881
# epoch:582  d_loss:0.2656  g_loss:2.3242
# epoch:583  d_loss:0.1690  g_loss:2.6192
# epoch:584  d_loss:0.3152  g_loss:2.8482
# epoch:585  d_loss:0.2948  g_loss:2.5583
# epoch:586  d_loss:0.3583  g_loss:2.3883
# epoch:587  d_loss:0.1236  g_loss:3.3002
# epoch:588  d_loss:0.3129  g_loss:2.9860
# epoch:589  d_loss:0.3888  g_loss:2.2296
# epoch:590  d_loss:0.4680  g_loss:1.8404
# epoch:591  d_loss:0.3401  g_loss:2.3509
# epoch:592  d_loss:0.2808  g_loss:3.1019
# epoch:593  d_loss:0.3136  g_loss:3.8901
# epoch:594  d_loss:0.2283  g_loss:3.0511
# epoch:595  d_loss:0.4927  g_loss:1.9081
# epoch:596  d_loss:0.4926  g_loss:1.8291
# epoch:597  d_loss:0.3108  g_loss:1.6002
# epoch:598  d_loss:0.2812  g_loss:2.3679
# epoch:599  d_loss:0.3091  g_loss:2.9613
# epoch:600  d_loss:0.3137  g_loss:2.5240
# epoch:601  d_loss:0.3051  g_loss:2.1072
# epoch:602  d_loss:0.1983  g_loss:2.0072
# epoch:603  d_loss:0.2380  g_loss:2.1374
# epoch:604  d_loss:0.2652  g_loss:2.3332
# epoch:605  d_loss:0.1891  g_loss:2.9696
# epoch:606  d_loss:0.2739  g_loss:2.6427
# epoch:607  d_loss:0.2095  g_loss:3.1569
# epoch:608  d_loss:0.2377  g_loss:2.5190
# epoch:609  d_loss:0.1851  g_loss:2.0282
# epoch:610  d_loss:0.1498  g_loss:1.9122
# epoch:611  d_loss:0.2665  g_loss:2.2211
# epoch:612  d_loss:0.1753  g_loss:2.3617
# epoch:613  d_loss:0.3160  g_loss:2.5623
# epoch:614  d_loss:0.2927  g_loss:2.0590
# epoch:615  d_loss:0.1876  g_loss:2.6379
# epoch:616  d_loss:0.2331  g_loss:2.2977
# epoch:617  d_loss:0.2205  g_loss:2.0074
# epoch:618  d_loss:0.1751  g_loss:2.2003
# epoch:619  d_loss:0.2259  g_loss:2.7102
# epoch:620  d_loss:0.1706  g_loss:2.8484
# epoch:621  d_loss:0.2604  g_loss:2.3798
# epoch:622  d_loss:0.2206  g_loss:2.4363
# epoch:623  d_loss:0.2651  g_loss:2.5997
# epoch:624  d_loss:0.3529  g_loss:1.9279
# epoch:625  d_loss:0.3381  g_loss:2.1928
# epoch:626  d_loss:0.3836  g_loss:1.7103
# epoch:627  d_loss:0.3944  g_loss:2.2716
# epoch:628  d_loss:0.2672  g_loss:2.6666
# epoch:629  d_loss:0.3885  g_loss:2.4084
# epoch:630  d_loss:0.5635  g_loss:1.4919
# epoch:631  d_loss:0.4008  g_loss:1.4647
# epoch:632  d_loss:0.7632  g_loss:1.7340
# epoch:633  d_loss:0.5724  g_loss:1.8758
# epoch:634  d_loss:0.6083  g_loss:2.3959
# epoch:635  d_loss:0.5325  g_loss:1.9916
# epoch:636  d_loss:0.4258  g_loss:2.0772
# epoch:637  d_loss:0.4208  g_loss:2.2787
# epoch:638  d_loss:0.2446  g_loss:2.7950
# epoch:639  d_loss:0.2278  g_loss:2.8384
# epoch:640  d_loss:0.2539  g_loss:2.6714
# epoch:641  d_loss:0.3134  g_loss:2.4036
# epoch:642  d_loss:0.2556  g_loss:2.2903
# epoch:643  d_loss:0.2709  g_loss:2.6443
# epoch:644  d_loss:0.2047  g_loss:2.6945
# epoch:645  d_loss:0.2870  g_loss:2.3061
# epoch:646  d_loss:0.3237  g_loss:2.1862
# epoch:647  d_loss:0.2902  g_loss:1.6770
# epoch:648  d_loss:0.1901  g_loss:1.6927
# epoch:649  d_loss:0.3243  g_loss:1.6444
# epoch:650  d_loss:0.2610  g_loss:2.5151
# epoch:651  d_loss:0.2818  g_loss:2.3154
# epoch:652  d_loss:0.3539  g_loss:2.0261
# epoch:653  d_loss:0.4223  g_loss:1.3850
# epoch:654  d_loss:0.3507  g_loss:1.5731
# epoch:655  d_loss:0.3426  g_loss:1.8074
# epoch:656  d_loss:0.3066  g_loss:1.9240
# epoch:657  d_loss:0.4454  g_loss:1.6083
# epoch:658  d_loss:0.4283  g_loss:1.4836
# epoch:659  d_loss:0.4369  g_loss:1.5502
# epoch:660  d_loss:0.4140  g_loss:1.7337
# epoch:661  d_loss:0.4822  g_loss:2.0124
# epoch:662  d_loss:0.4053  g_loss:1.3285
# epoch:663  d_loss:0.4329  g_loss:1.7659
# epoch:664  d_loss:0.3920  g_loss:1.3583
# epoch:665  d_loss:0.5119  g_loss:1.3722
# epoch:666  d_loss:0.5885  g_loss:1.6868
# epoch:667  d_loss:0.4805  g_loss:2.3602
# epoch:668  d_loss:0.5813  g_loss:1.9385
# epoch:669  d_loss:0.4640  g_loss:2.0398
# epoch:670  d_loss:0.5813  g_loss:1.8739
# epoch:671  d_loss:0.8551  g_loss:1.5126
# epoch:672  d_loss:0.8489  g_loss:1.2987
# epoch:673  d_loss:0.4062  g_loss:1.6802
# epoch:674  d_loss:0.3491  g_loss:1.9291
# epoch:675  d_loss:0.4897  g_loss:2.2366
# epoch:676  d_loss:0.5024  g_loss:1.4479
# epoch:677  d_loss:0.7953  g_loss:1.0193
# epoch:678  d_loss:0.7184  g_loss:1.0278
# epoch:679  d_loss:0.3604  g_loss:1.7317
# epoch:680  d_loss:0.4319  g_loss:2.1436
# epoch:681  d_loss:0.3792  g_loss:1.8995
# epoch:682  d_loss:0.5667  g_loss:1.3732
# epoch:683  d_loss:0.7212  g_loss:0.9271
# epoch:684  d_loss:0.4478  g_loss:0.7723
# epoch:685  d_loss:0.4990  g_loss:0.5968
# epoch:686  d_loss:0.5491  g_loss:0.5982
# epoch:687  d_loss:0.4470  g_loss:0.9859
# epoch:688  d_loss:0.5184  g_loss:1.2612
# epoch:689  d_loss:0.4741  g_loss:1.3342
# epoch:690  d_loss:0.7927  g_loss:1.7334
# epoch:691  d_loss:0.5206  g_loss:1.5716
# epoch:692  d_loss:0.4648  g_loss:1.8051
# epoch:693  d_loss:0.2860  g_loss:1.8725
# epoch:694  d_loss:0.4421  g_loss:2.1136
# epoch:695  d_loss:0.3323  g_loss:2.1610
# epoch:696  d_loss:0.5746  g_loss:2.2880
# epoch:697  d_loss:0.7230  g_loss:2.1535
# epoch:698  d_loss:0.5034  g_loss:2.8411
# epoch:699  d_loss:0.5747  g_loss:2.8157
# epoch:700  d_loss:0.6029  g_loss:2.5306
# epoch:701  d_loss:0.8735  g_loss:2.0775
# epoch:702  d_loss:0.7832  g_loss:1.3435
# epoch:703  d_loss:0.6519  g_loss:1.2103
# epoch:704  d_loss:0.4342  g_loss:1.6256
# epoch:705  d_loss:0.4692  g_loss:1.9491
# epoch:706  d_loss:0.5340  g_loss:1.7123
# epoch:707  d_loss:0.5856  g_loss:1.9535
# epoch:708  d_loss:0.3440  g_loss:2.1123
# epoch:709  d_loss:0.5368  g_loss:2.3556
# epoch:710  d_loss:0.4535  g_loss:2.1415
# epoch:711  d_loss:0.4780  g_loss:1.8652
# epoch:712  d_loss:0.5641  g_loss:1.6988
# epoch:713  d_loss:0.3777  g_loss:1.6448
# epoch:714  d_loss:0.4299  g_loss:1.7253
# epoch:715  d_loss:0.4618  g_loss:1.6699
# epoch:716  d_loss:0.4175  g_loss:1.7534
# epoch:717  d_loss:0.5140  g_loss:1.7230
# epoch:718  d_loss:0.4035  g_loss:1.5553
# epoch:719  d_loss:0.4342  g_loss:1.7944
# epoch:720  d_loss:0.5478  g_loss:1.5975
# epoch:721  d_loss:0.3860  g_loss:2.0200
# epoch:722  d_loss:0.5737  g_loss:1.6778
# epoch:723  d_loss:0.5417  g_loss:1.5939
# epoch:724  d_loss:0.4242  g_loss:1.8920
# epoch:725  d_loss:0.5358  g_loss:1.8202
# epoch:726  d_loss:0.4724  g_loss:1.5582
# epoch:727  d_loss:0.4041  g_loss:1.7052
# epoch:728  d_loss:0.5070  g_loss:1.3861
# epoch:729  d_loss:0.4754  g_loss:1.5113
# epoch:730  d_loss:0.4329  g_loss:1.7637
# epoch:731  d_loss:0.3831  g_loss:1.8305
# epoch:732  d_loss:0.5672  g_loss:2.1212
# epoch:733  d_loss:0.5940  g_loss:1.4295
# epoch:734  d_loss:0.3907  g_loss:1.1080
# epoch:735  d_loss:0.4821  g_loss:1.4250
# epoch:736  d_loss:0.3162  g_loss:1.9768
# epoch:737  d_loss:0.4036  g_loss:2.4126
# epoch:738  d_loss:0.5272  g_loss:1.7735
# epoch:739  d_loss:0.3664  g_loss:1.4038
# epoch:740  d_loss:0.4249  g_loss:1.1601
# epoch:741  d_loss:0.5051  g_loss:1.3473
# epoch:742  d_loss:0.4714  g_loss:1.6733
# epoch:743  d_loss:0.5154  g_loss:1.7617
# epoch:744  d_loss:0.5969  g_loss:1.6920
# epoch:745  d_loss:0.5670  g_loss:1.6417
# epoch:746  d_loss:0.8028  g_loss:1.7203
# epoch:747  d_loss:0.5178  g_loss:1.4528
# epoch:748  d_loss:0.5162  g_loss:1.8248
# epoch:749  d_loss:0.7130  g_loss:1.6318
# epoch:750  d_loss:0.8051  g_loss:1.5945
# epoch:751  d_loss:0.5820  g_loss:1.5605
# epoch:752  d_loss:0.4462  g_loss:1.8484
# epoch:753  d_loss:0.3881  g_loss:1.9466
# epoch:754  d_loss:0.3756  g_loss:2.0619
# epoch:755  d_loss:0.3770  g_loss:2.1667
# epoch:756  d_loss:0.2306  g_loss:2.7080
# epoch:757  d_loss:0.3203  g_loss:2.2925
# epoch:758  d_loss:0.2769  g_loss:2.3617
# epoch:759  d_loss:0.1800  g_loss:2.3425
# epoch:760  d_loss:0.2360  g_loss:1.9830
# epoch:761  d_loss:0.1949  g_loss:2.4007
# epoch:762  d_loss:0.1979  g_loss:2.3326
# epoch:763  d_loss:0.2378  g_loss:2.3975
# epoch:764  d_loss:0.1810  g_loss:2.9402
# epoch:765  d_loss:0.1899  g_loss:2.8817
# epoch:766  d_loss:0.1736  g_loss:2.8396
# epoch:767  d_loss:0.1724  g_loss:3.1968
# epoch:768  d_loss:0.1355  g_loss:2.8102
# epoch:769  d_loss:0.1801  g_loss:3.0938
# epoch:770  d_loss:0.1920  g_loss:2.9644
# epoch:771  d_loss:0.3337  g_loss:2.7695
# epoch:772  d_loss:0.2781  g_loss:2.3428
# epoch:773  d_loss:0.2414  g_loss:2.7219
# epoch:774  d_loss:0.2484  g_loss:3.1902
# epoch:775  d_loss:0.4674  g_loss:2.9557
# epoch:776  d_loss:0.4128  g_loss:2.4257
# epoch:777  d_loss:0.5630  g_loss:1.9378
# epoch:778  d_loss:0.3948  g_loss:2.0966
# epoch:779  d_loss:0.4640  g_loss:1.8683
# epoch:780  d_loss:0.5978  g_loss:1.7883
# epoch:781  d_loss:0.5006  g_loss:2.5828
# epoch:782  d_loss:0.3056  g_loss:2.5809
# epoch:783  d_loss:0.5121  g_loss:2.4742
# epoch:784  d_loss:0.4836  g_loss:2.2764
# epoch:785  d_loss:0.4151  g_loss:2.4914
# epoch:786  d_loss:0.6775  g_loss:1.5704
# epoch:787  d_loss:0.6268  g_loss:2.0608
# epoch:788  d_loss:0.5353  g_loss:2.2301
# epoch:789  d_loss:0.3012  g_loss:2.6407
# epoch:790  d_loss:0.4812  g_loss:1.9157
# epoch:791  d_loss:0.5313  g_loss:1.8698
# epoch:792  d_loss:0.4296  g_loss:1.6373
# epoch:793  d_loss:0.4130  g_loss:1.7858
# epoch:794  d_loss:0.4226  g_loss:1.6961
# epoch:795  d_loss:0.3318  g_loss:2.6101
# epoch:796  d_loss:0.2902  g_loss:2.4712
# epoch:797  d_loss:0.2800  g_loss:2.2246
# epoch:798  d_loss:0.3771  g_loss:1.8304
# epoch:799  d_loss:0.3372  g_loss:2.2696
# epoch:800  d_loss:0.2440  g_loss:2.6095
# epoch:801  d_loss:0.2888  g_loss:2.5516
# epoch:802  d_loss:0.3320  g_loss:2.2572
# epoch:803  d_loss:0.3684  g_loss:2.1874
# epoch:804  d_loss:0.3758  g_loss:1.8964
# epoch:805  d_loss:0.3171  g_loss:2.0452
# epoch:806  d_loss:0.2651  g_loss:2.1774
# epoch:807  d_loss:0.2106  g_loss:3.2897
# epoch:808  d_loss:0.2396  g_loss:3.4232
# epoch:809  d_loss:0.2951  g_loss:3.0967
# epoch:810  d_loss:0.3405  g_loss:2.2628
# epoch:811  d_loss:0.1778  g_loss:2.5949
# epoch:812  d_loss:0.3291  g_loss:2.1640
# epoch:813  d_loss:0.3447  g_loss:2.3124
# epoch:814  d_loss:0.4507  g_loss:2.5458
# epoch:815  d_loss:0.3512  g_loss:2.7668
# epoch:816  d_loss:0.3700  g_loss:2.6333
# epoch:817  d_loss:0.4846  g_loss:2.3369
# epoch:818  d_loss:0.3008  g_loss:2.3183
# epoch:819  d_loss:0.3982  g_loss:2.3596
# epoch:820  d_loss:0.4179  g_loss:1.8833
# epoch:821  d_loss:0.3924  g_loss:2.2935
# epoch:822  d_loss:0.3235  g_loss:2.6352
# epoch:823  d_loss:0.4270  g_loss:2.2869
# epoch:824  d_loss:0.4369  g_loss:2.0649
# epoch:825  d_loss:0.5559  g_loss:1.9360
# epoch:826  d_loss:0.3206  g_loss:2.1510
# epoch:827  d_loss:0.4012  g_loss:2.3211
# epoch:828  d_loss:0.4053  g_loss:2.2550
# epoch:829  d_loss:0.5147  g_loss:2.4701
# epoch:830  d_loss:0.4907  g_loss:2.2952
# epoch:831  d_loss:0.6625  g_loss:1.8899
# epoch:832  d_loss:0.3532  g_loss:1.5099
# epoch:833  d_loss:0.5414  g_loss:1.9206
# epoch:834  d_loss:0.4195  g_loss:2.5616
# epoch:835  d_loss:0.4229  g_loss:2.5658
# epoch:836  d_loss:0.4088  g_loss:2.8953
# epoch:837  d_loss:0.4360  g_loss:2.4103
# epoch:838  d_loss:0.4415  g_loss:3.0006
# epoch:839  d_loss:0.4898  g_loss:2.4651
# epoch:840  d_loss:0.4090  g_loss:1.8673
# epoch:841  d_loss:0.3573  g_loss:2.4495
# epoch:842  d_loss:0.3656  g_loss:2.2113
# epoch:843  d_loss:0.2855  g_loss:3.0810
# epoch:844  d_loss:0.3982  g_loss:3.0130
# epoch:845  d_loss:0.3769  g_loss:2.7833
# epoch:846  d_loss:0.3284  g_loss:2.5882
# epoch:847  d_loss:0.5109  g_loss:1.9140
# epoch:848  d_loss:0.4285  g_loss:2.6256
# epoch:849  d_loss:0.2838  g_loss:3.2042
# epoch:850  d_loss:0.4665  g_loss:3.6906
# epoch:851  d_loss:0.3819  g_loss:3.8534
# epoch:852  d_loss:0.3138  g_loss:2.7375
# epoch:853  d_loss:0.2931  g_loss:2.5704
# epoch:854  d_loss:0.3713  g_loss:2.5525
# epoch:855  d_loss:0.3032  g_loss:2.6761
# epoch:856  d_loss:0.1924  g_loss:2.9617
# epoch:857  d_loss:0.2920  g_loss:3.2603
# epoch:858  d_loss:0.3092  g_loss:3.2460
# epoch:859  d_loss:0.3360  g_loss:2.9465
# epoch:860  d_loss:0.2898  g_loss:2.6217
# epoch:861  d_loss:0.3079  g_loss:2.2860
# epoch:862  d_loss:0.2781  g_loss:2.3606
# epoch:863  d_loss:0.3231  g_loss:2.3977
# epoch:864  d_loss:0.1702  g_loss:3.4358
# epoch:865  d_loss:0.1107  g_loss:4.1925
# epoch:866  d_loss:0.3123  g_loss:3.4798
# epoch:867  d_loss:0.2108  g_loss:2.9910
# epoch:868  d_loss:0.2292  g_loss:2.7866
# epoch:869  d_loss:0.1431  g_loss:2.6689
# epoch:870  d_loss:0.1662  g_loss:2.3643
# epoch:871  d_loss:0.2062  g_loss:2.7953
# epoch:872  d_loss:0.2055  g_loss:2.5877
# epoch:873  d_loss:0.2225  g_loss:2.5643
# epoch:874  d_loss:0.2036  g_loss:3.0841
# epoch:875  d_loss:0.3490  g_loss:2.7877
# epoch:876  d_loss:0.2523  g_loss:3.0003
# epoch:877  d_loss:0.4248  g_loss:2.3897
# epoch:878  d_loss:0.3933  g_loss:2.2151
# epoch:879  d_loss:0.5273  g_loss:2.4770
# epoch:880  d_loss:0.3889  g_loss:2.5025
# epoch:881  d_loss:0.3576  g_loss:1.7044
# epoch:882  d_loss:0.2913  g_loss:1.8607
# epoch:883  d_loss:0.4738  g_loss:2.2821
# epoch:884  d_loss:0.5681  g_loss:1.7627
# epoch:885  d_loss:0.4430  g_loss:1.7590
# epoch:886  d_loss:0.5197  g_loss:1.4861
# epoch:887  d_loss:0.5258  g_loss:1.6254
# epoch:888  d_loss:0.5489  g_loss:1.7770
# epoch:889  d_loss:0.5115  g_loss:1.7983
# epoch:890  d_loss:0.5627  g_loss:1.3493
# epoch:891  d_loss:0.3806  g_loss:1.3207
# epoch:892  d_loss:0.4331  g_loss:1.2505
# epoch:893  d_loss:0.4237  g_loss:1.2114
# epoch:894  d_loss:0.4663  g_loss:1.3875
# epoch:895  d_loss:0.5826  g_loss:1.4580
# epoch:896  d_loss:0.4161  g_loss:2.0571
# epoch:897  d_loss:0.3479  g_loss:1.6177
# epoch:898  d_loss:0.2793  g_loss:1.8334
# epoch:899  d_loss:0.3348  g_loss:2.1256
# epoch:900  d_loss:0.2962  g_loss:2.0628
# epoch:901  d_loss:0.3562  g_loss:1.9003
# epoch:902  d_loss:0.3855  g_loss:1.6871
# epoch:903  d_loss:0.3175  g_loss:1.6626
# epoch:904  d_loss:0.3311  g_loss:1.8027
# epoch:905  d_loss:0.2815  g_loss:2.3636
# epoch:906  d_loss:0.2015  g_loss:2.5413
# epoch:907  d_loss:0.2861  g_loss:2.4026
# epoch:908  d_loss:0.4017  g_loss:1.7625
# epoch:909  d_loss:0.3610  g_loss:1.7577
# epoch:910  d_loss:0.2918  g_loss:2.2802
# epoch:911  d_loss:0.3051  g_loss:2.4831
# epoch:912  d_loss:0.2836  g_loss:2.5093
# epoch:913  d_loss:0.3022  g_loss:2.3194
# epoch:914  d_loss:0.3354  g_loss:2.1863
# epoch:915  d_loss:0.3318  g_loss:2.1089
# epoch:916  d_loss:0.3835  g_loss:2.2783
# epoch:917  d_loss:0.2965  g_loss:2.4785
# epoch:918  d_loss:0.3368  g_loss:2.1462
# epoch:919  d_loss:0.4098  g_loss:2.4905
# epoch:920  d_loss:0.4065  g_loss:2.3241
# epoch:921  d_loss:0.2898  g_loss:2.4313
# epoch:922  d_loss:0.4755  g_loss:2.0390
# epoch:923  d_loss:0.3762  g_loss:2.0031
# epoch:924  d_loss:0.3930  g_loss:1.9255
# epoch:925  d_loss:0.5092  g_loss:1.8282
# epoch:926  d_loss:0.4997  g_loss:1.9309
# epoch:927  d_loss:0.4073  g_loss:2.4371
# epoch:928  d_loss:0.3743  g_loss:2.3609
# epoch:929  d_loss:0.5354  g_loss:1.7548
# epoch:930  d_loss:0.5328  g_loss:1.3980
# epoch:931  d_loss:0.3462  g_loss:1.4933
# epoch:932  d_loss:0.4441  g_loss:1.7119
# epoch:933  d_loss:0.3676  g_loss:2.2029
# epoch:934  d_loss:0.3065  g_loss:2.4794
# epoch:935  d_loss:0.4533  g_loss:2.2907
# epoch:936  d_loss:0.3820  g_loss:2.2013
# epoch:937  d_loss:0.2922  g_loss:1.9860
# epoch:938  d_loss:0.4810  g_loss:1.9045
# epoch:939  d_loss:0.3972  g_loss:2.0234
# epoch:940  d_loss:0.2609  g_loss:2.4282
# epoch:941  d_loss:0.3209  g_loss:2.6559
# epoch:942  d_loss:0.2748  g_loss:3.0862
# epoch:943  d_loss:0.3211  g_loss:2.3053
# epoch:944  d_loss:0.3340  g_loss:2.5542
# epoch:945  d_loss:0.3055  g_loss:2.0104
# epoch:946  d_loss:0.3202  g_loss:2.4631
# epoch:947  d_loss:0.3065  g_loss:2.4129
# epoch:948  d_loss:0.3396  g_loss:2.4290
# epoch:949  d_loss:0.4569  g_loss:2.6005
# epoch:950  d_loss:0.3967  g_loss:1.9957
# epoch:951  d_loss:0.3373  g_loss:1.9990
# epoch:952  d_loss:0.3546  g_loss:1.6841
# epoch:953  d_loss:0.3579  g_loss:2.4233
# epoch:954  d_loss:0.3980  g_loss:2.1056
# epoch:955  d_loss:0.4698  g_loss:1.9298
# epoch:956  d_loss:0.4143  g_loss:2.2154
# epoch:957  d_loss:0.3784  g_loss:2.4859
# epoch:958  d_loss:0.3185  g_loss:2.1887
# epoch:959  d_loss:0.4609  g_loss:1.6924
# epoch:960  d_loss:0.4156  g_loss:1.4216
# epoch:961  d_loss:0.3548  g_loss:2.0781
# epoch:962  d_loss:0.2397  g_loss:2.2013
# epoch:963  d_loss:0.3893  g_loss:2.8015
# epoch:964  d_loss:0.4177  g_loss:2.9956
# epoch:965  d_loss:0.3664  g_loss:2.4796
# epoch:966  d_loss:0.2717  g_loss:1.8372
# epoch:967  d_loss:0.3117  g_loss:1.7316
# epoch:968  d_loss:0.3086  g_loss:2.2522
# epoch:969  d_loss:0.3612  g_loss:2.4017
# epoch:970  d_loss:0.4108  g_loss:2.6696
# epoch:971  d_loss:0.2381  g_loss:2.6787
# epoch:972  d_loss:0.3196  g_loss:2.7772
# epoch:973  d_loss:0.3803  g_loss:2.0858
# epoch:974  d_loss:0.3132  g_loss:1.9224
# epoch:975  d_loss:0.2661  g_loss:2.2733
# epoch:976  d_loss:0.3688  g_loss:1.9365
# epoch:977  d_loss:0.2642  g_loss:2.3484
# epoch:978  d_loss:0.3027  g_loss:2.6752
# epoch:979  d_loss:0.2324  g_loss:2.7210
# epoch:980  d_loss:0.3787  g_loss:1.7459
# epoch:981  d_loss:0.1988  g_loss:1.9504
# epoch:982  d_loss:0.2727  g_loss:2.1078
# epoch:983  d_loss:0.3761  g_loss:1.9502
# epoch:984  d_loss:0.3861  g_loss:2.1109
# epoch:985  d_loss:0.3101  g_loss:2.2153
# epoch:986  d_loss:0.2788  g_loss:2.6050
# epoch:987  d_loss:0.3315  g_loss:2.7141
# epoch:988  d_loss:0.2903  g_loss:2.8122
# epoch:989  d_loss:0.3506  g_loss:2.3080
# epoch:990  d_loss:0.5207  g_loss:2.1050
# epoch:991  d_loss:0.3228  g_loss:2.6350
# epoch:992  d_loss:0.5493  g_loss:2.3989
# epoch:993  d_loss:0.3302  g_loss:2.1818
# epoch:994  d_loss:0.4954  g_loss:1.9952
# epoch:995  d_loss:0.3693  g_loss:2.6452
# epoch:996  d_loss:0.4285  g_loss:2.0944
# epoch:997  d_loss:0.5861  g_loss:1.6018
# epoch:998  d_loss:0.6453  g_loss:1.8609
# epoch:999  d_loss:0.3936  g_loss:1.9499
# epoch:1000  d_loss:0.3917  g_loss:2.3269
# epoch:1001  d_loss:0.5837  g_loss:2.8030
# epoch:1002  d_loss:0.4363  g_loss:1.9755
# epoch:1003  d_loss:0.5616  g_loss:1.8890
# epoch:1004  d_loss:0.4297  g_loss:1.8383
# epoch:1005  d_loss:0.5079  g_loss:1.6082
# epoch:1006  d_loss:0.4544  g_loss:1.8530
# epoch:1007  d_loss:0.4767  g_loss:2.3320
# epoch:1008  d_loss:0.3357  g_loss:2.4827
# epoch:1009  d_loss:0.3362  g_loss:2.6124
# epoch:1010  d_loss:0.3752  g_loss:2.4377
# epoch:1011  d_loss:0.3976  g_loss:2.2747
# epoch:1012  d_loss:0.3969  g_loss:2.2975
# epoch:1013  d_loss:0.2624  g_loss:1.9756
# epoch:1014  d_loss:0.2632  g_loss:1.6275
# epoch:1015  d_loss:0.3366  g_loss:2.4602
# epoch:1016  d_loss:0.3152  g_loss:2.5454
# epoch:1017  d_loss:0.2209  g_loss:3.1130
# epoch:1018  d_loss:0.2049  g_loss:3.0122
# epoch:1019  d_loss:0.1555  g_loss:3.0574
# epoch:1020  d_loss:0.1387  g_loss:3.3222
# epoch:1021  d_loss:0.2355  g_loss:2.8073
# epoch:1022  d_loss:0.2069  g_loss:2.7840
# epoch:1023  d_loss:0.2004  g_loss:2.9426
# epoch:1024  d_loss:0.3775  g_loss:2.8506
# epoch:1025  d_loss:0.3505  g_loss:2.8935
# epoch:1026  d_loss:0.2998  g_loss:2.9315
# epoch:1027  d_loss:0.1943  g_loss:2.9541
# epoch:1028  d_loss:0.2542  g_loss:2.7320
# epoch:1029  d_loss:0.4028  g_loss:3.4954
# epoch:1030  d_loss:0.3424  g_loss:2.5017
# epoch:1031  d_loss:0.3560  g_loss:2.9176
# epoch:1032  d_loss:0.2790  g_loss:3.0820
# epoch:1033  d_loss:0.3500  g_loss:3.5049
# epoch:1034  d_loss:0.3384  g_loss:3.2088
# epoch:1035  d_loss:0.4053  g_loss:2.7539
# epoch:1036  d_loss:0.5037  g_loss:2.2798
# epoch:1037  d_loss:0.3334  g_loss:2.6539
# epoch:1038  d_loss:0.3505  g_loss:2.8364
# epoch:1039  d_loss:0.3715  g_loss:3.3271
# epoch:1040  d_loss:0.5069  g_loss:2.5403
# epoch:1041  d_loss:0.4953  g_loss:1.8021
# epoch:1042  d_loss:0.6351  g_loss:1.6763
# epoch:1043  d_loss:0.4436  g_loss:2.8268
# epoch:1044  d_loss:0.2816  g_loss:2.9801
# epoch:1045  d_loss:0.4321  g_loss:2.9086
# epoch:1046  d_loss:0.4181  g_loss:2.6312
# epoch:1047  d_loss:0.4442  g_loss:2.2220
# epoch:1048  d_loss:0.3635  g_loss:2.2368
# epoch:1049  d_loss:0.2868  g_loss:3.2916
# epoch:1050  d_loss:0.2593  g_loss:3.1875
# epoch:1051  d_loss:0.2730  g_loss:2.9739
# epoch:1052  d_loss:0.1912  g_loss:2.4565
# epoch:1053  d_loss:0.2143  g_loss:2.0375
# epoch:1054  d_loss:0.2529  g_loss:2.5893
# epoch:1055  d_loss:0.2534  g_loss:2.9826
# epoch:1056  d_loss:0.1599  g_loss:3.3943
# epoch:1057  d_loss:0.2561  g_loss:2.9856
# epoch:1058  d_loss:0.2042  g_loss:3.0762
# epoch:1059  d_loss:0.2783  g_loss:2.1091
# epoch:1060  d_loss:0.2863  g_loss:2.3761
# epoch:1061  d_loss:0.3523  g_loss:2.2726
# epoch:1062  d_loss:0.3106  g_loss:2.2821
# epoch:1063  d_loss:0.3127  g_loss:2.7320
# epoch:1064  d_loss:0.2277  g_loss:2.8061
# epoch:1065  d_loss:0.2911  g_loss:2.8943
# epoch:1066  d_loss:0.4398  g_loss:2.6530
# epoch:1067  d_loss:0.3275  g_loss:1.9855
# epoch:1068  d_loss:0.4172  g_loss:1.9181
# epoch:1069  d_loss:0.3646  g_loss:2.0422
# epoch:1070  d_loss:0.4700  g_loss:1.9774
# epoch:1071  d_loss:0.3731  g_loss:2.3248
# epoch:1072  d_loss:0.3213  g_loss:2.9258
# epoch:1073  d_loss:0.3145  g_loss:3.3055
# epoch:1074  d_loss:0.3501  g_loss:2.6769
# epoch:1075  d_loss:0.5569  g_loss:2.2071
# epoch:1076  d_loss:0.3796  g_loss:2.0449
# epoch:1077  d_loss:0.4131  g_loss:2.6030
# epoch:1078  d_loss:0.3623  g_loss:2.7510
# epoch:1079  d_loss:0.3150  g_loss:2.6608
# epoch:1080  d_loss:0.5884  g_loss:2.3432
# epoch:1081  d_loss:0.3289  g_loss:2.8079
# epoch:1082  d_loss:0.4539  g_loss:2.5224
# epoch:1083  d_loss:0.3980  g_loss:1.6793
# epoch:1084  d_loss:0.4177  g_loss:1.4893
# epoch:1085  d_loss:0.4953  g_loss:1.9592
# epoch:1086  d_loss:0.4351  g_loss:2.6557
# epoch:1087  d_loss:0.3990  g_loss:3.0547
# epoch:1088  d_loss:0.5689  g_loss:2.5471
# epoch:1089  d_loss:0.3745  g_loss:2.2916
# epoch:1090  d_loss:0.6562  g_loss:1.5818
# epoch:1091  d_loss:0.7208  g_loss:1.4917
# epoch:1092  d_loss:0.3759  g_loss:1.9771
# epoch:1093  d_loss:0.3251  g_loss:2.1404
# epoch:1094  d_loss:0.3545  g_loss:3.0398
# epoch:1095  d_loss:0.3823  g_loss:2.5808
# epoch:1096  d_loss:0.3912  g_loss:2.1787
# epoch:1097  d_loss:0.3422  g_loss:1.9122
# epoch:1098  d_loss:0.3320  g_loss:1.9036
# epoch:1099  d_loss:0.2357  g_loss:2.7469
# epoch:1100  d_loss:0.2293  g_loss:3.0054
# epoch:1101  d_loss:0.1838  g_loss:3.0892
# epoch:1102  d_loss:0.2651  g_loss:3.4150
# epoch:1103  d_loss:0.2733  g_loss:2.6124
# epoch:1104  d_loss:0.2628  g_loss:2.2546
# epoch:1105  d_loss:0.2421  g_loss:2.3417
# epoch:1106  d_loss:0.2672  g_loss:2.5147
# epoch:1107  d_loss:0.2034  g_loss:3.2779
# epoch:1108  d_loss:0.2339  g_loss:3.6097
# epoch:1109  d_loss:0.1740  g_loss:3.4609
# epoch:1110  d_loss:0.4472  g_loss:2.3693
# epoch:1111  d_loss:0.3183  g_loss:2.8942
# epoch:1112  d_loss:0.1920  g_loss:2.4728
# epoch:1113  d_loss:0.2963  g_loss:2.7880
# epoch:1114  d_loss:0.3340  g_loss:3.5279
# epoch:1115  d_loss:0.2878  g_loss:3.1714
# epoch:1116  d_loss:0.4174  g_loss:3.2050
# epoch:1117  d_loss:0.2823  g_loss:2.6686
# epoch:1118  d_loss:0.5951  g_loss:2.1526
# epoch:1119  d_loss:0.4583  g_loss:2.7095
# epoch:1120  d_loss:0.5352  g_loss:2.6071
# epoch:1121  d_loss:0.4614  g_loss:2.4690
# epoch:1122  d_loss:0.2782  g_loss:2.1258
# epoch:1123  d_loss:0.4345  g_loss:2.4277
# epoch:1124  d_loss:0.5172  g_loss:2.3028
# epoch:1125  d_loss:0.5032  g_loss:1.8781
# epoch:1126  d_loss:0.3691  g_loss:1.6911
# epoch:1127  d_loss:0.5200  g_loss:2.2047
# epoch:1128  d_loss:0.2654  g_loss:2.3002
# epoch:1129  d_loss:0.2891  g_loss:2.5532
# epoch:1130  d_loss:0.3319  g_loss:3.0413
# epoch:1131  d_loss:0.4523  g_loss:2.3965
# epoch:1132  d_loss:0.4708  g_loss:2.0333
# epoch:1133  d_loss:0.4110  g_loss:1.8477
# epoch:1134  d_loss:0.2679  g_loss:2.5397
# epoch:1135  d_loss:0.3834  g_loss:2.1599
# epoch:1136  d_loss:0.3094  g_loss:2.5989
# epoch:1137  d_loss:0.3087  g_loss:2.6170
# epoch:1138  d_loss:0.2707  g_loss:2.7914
# epoch:1139  d_loss:0.3095  g_loss:2.6365
# epoch:1140  d_loss:0.3816  g_loss:1.8365
# epoch:1141  d_loss:0.2892  g_loss:2.3627
# epoch:1142  d_loss:0.3300  g_loss:2.1601
# epoch:1143  d_loss:0.2676  g_loss:2.6831
# epoch:1144  d_loss:0.4298  g_loss:2.8519
# epoch:1145  d_loss:0.4059  g_loss:2.4203
# epoch:1146  d_loss:0.3860  g_loss:2.4756
# epoch:1147  d_loss:0.4346  g_loss:1.6335
# epoch:1148  d_loss:0.3733  g_loss:2.1675
# epoch:1149  d_loss:0.3157  g_loss:2.1399
# epoch:1150  d_loss:0.3046  g_loss:2.1152
# epoch:1151  d_loss:0.2601  g_loss:1.8232
# epoch:1152  d_loss:0.3459  g_loss:2.2373
# epoch:1153  d_loss:0.3975  g_loss:1.7417
# epoch:1154  d_loss:0.5005  g_loss:1.9711
# epoch:1155  d_loss:0.3675  g_loss:1.8472
# epoch:1156  d_loss:0.3854  g_loss:2.0739
# epoch:1157  d_loss:0.3896  g_loss:2.1535
# epoch:1158  d_loss:0.5094  g_loss:1.8159
# epoch:1159  d_loss:0.5240  g_loss:1.7777
# epoch:1160  d_loss:0.3953  g_loss:1.8155
# epoch:1161  d_loss:0.4491  g_loss:1.6446
# epoch:1162  d_loss:0.5545  g_loss:1.7643
# epoch:1163  d_loss:0.5027  g_loss:1.9471
# epoch:1164  d_loss:0.4361  g_loss:2.2942
# epoch:1165  d_loss:0.3885  g_loss:2.5385
# epoch:1166  d_loss:0.4525  g_loss:1.8089
# epoch:1167  d_loss:0.7000  g_loss:1.3383
# epoch:1168  d_loss:0.5676  g_loss:1.6551
# epoch:1169  d_loss:0.5155  g_loss:1.8644
# epoch:1170  d_loss:0.4865  g_loss:2.4522
# epoch:1171  d_loss:0.4103  g_loss:2.3655
# epoch:1172  d_loss:0.3802  g_loss:2.2542
# epoch:1173  d_loss:0.4723  g_loss:2.2925
# epoch:1174  d_loss:0.4267  g_loss:2.3193
# ...
# epoch:3619  d_loss:0.5052  g_loss:1.7705
# epoch:3620  d_loss:0.4910  g_loss:2.2537
# epoch:3621  d_loss:0.5123  g_loss:1.6704
# epoch:3622  d_loss:0.3710  g_loss:1.7268
# epoch:3623  d_loss:0.4590  g_loss:1.7545
# epoch:3624  d_loss:0.5403  g_loss:1.8009
# epoch:3625  d_loss:0.4738  g_loss:2.4308
# epoch:3626  d_loss:0.5603  g_loss:2.2526
# epoch:3627  d_loss:0.4804  g_loss:2.1679
# epoch:3628  d_loss:0.6177  g_loss:1.7089
# epoch:3629  d_loss:0.3869  g_loss:1.8508
# epoch:3630  d_loss:0.5492  g_loss:1.7383
# epoch:3631  d_loss:0.4793  g_loss:1.8602
# epoch:3632  d_loss:0.4746  g_loss:2.0599
# epoch:3633  d_loss:0.4323  g_loss:2.3174
# epoch:3634  d_loss:0.4553  g_loss:2.4825
# epoch:3635  d_loss:0.4461  g_loss:2.3807
# epoch:3636  d_loss:0.4254  g_loss:1.9700
# epoch:3637  d_loss:0.4888  g_loss:2.1252
# epoch:3638  d_loss:0.3780  g_loss:1.6014
# epoch:3639  d_loss:0.4874  g_loss:1.7990
# epoch:3640  d_loss:0.5011  g_loss:1.9147
# epoch:3641  d_loss:0.2942  g_loss:1.9704
# epoch:3642  d_loss:0.4097  g_loss:2.1645
# epoch:3643  d_loss:0.4455  g_loss:2.2552
# epoch:3644  d_loss:0.5118  g_loss:2.4486
# epoch:3645  d_loss:0.4720  g_loss:1.6642
# epoch:3646  d_loss:0.4146  g_loss:1.4325
# epoch:3647  d_loss:0.4169  g_loss:1.6561
# epoch:3648  d_loss:0.3632  g_loss:1.7690
# epoch:3649  d_loss:0.3366  g_loss:1.7725
# epoch:3650  d_loss:0.3723  g_loss:2.0988
# epoch:3651  d_loss:0.4615  g_loss:2.5143
# epoch:3652  d_loss:0.5117  g_loss:1.9277
# epoch:3653  d_loss:0.3997  g_loss:1.9153
# epoch:3654  d_loss:0.5392  g_loss:1.7376
# epoch:3655  d_loss:0.4515  g_loss:1.6461
# epoch:3656  d_loss:0.5923  g_loss:1.4611
# epoch:3657  d_loss:0.4291  g_loss:2.2316
# epoch:3658  d_loss:0.5384  g_loss:2.0313
# epoch:3659  d_loss:0.3815  g_loss:2.5316
# epoch:3660  d_loss:0.6713  g_loss:2.2537
# epoch:3661  d_loss:0.4582  g_loss:2.0631
# epoch:3662  d_loss:0.4903  g_loss:1.2132
# epoch:3663  d_loss:0.4310  g_loss:1.7711
# epoch:3664  d_loss:0.4330  g_loss:1.7592
# epoch:3665  d_loss:0.5695  g_loss:1.4845
# epoch:3666  d_loss:0.4790  g_loss:1.9455
# epoch:3667  d_loss:0.3878  g_loss:2.6309
# epoch:3668  d_loss:0.7813  g_loss:1.2941
# epoch:3669  d_loss:0.7468  g_loss:1.4516
# epoch:3670  d_loss:0.4805  g_loss:1.4833
# epoch:3671  d_loss:0.5708  g_loss:1.8062
# epoch:3672  d_loss:0.6144  g_loss:1.5752
# epoch:3673  d_loss:0.5936  g_loss:2.0051
# epoch:3674  d_loss:0.5531  g_loss:1.8362
# epoch:3675  d_loss:0.4212  g_loss:1.7756
# epoch:3676  d_loss:0.6477  g_loss:1.5927
# epoch:3677  d_loss:0.4142  g_loss:1.8865
# epoch:3678  d_loss:0.4521  g_loss:1.7062
# epoch:3679  d_loss:0.5713  g_loss:1.6103
# epoch:3680  d_loss:0.5338  g_loss:1.4021
# epoch:3681  d_loss:0.5425  g_loss:1.6793
# epoch:3682  d_loss:0.5214  g_loss:1.9010
# epoch:3683  d_loss:0.4823  g_loss:1.8576
# epoch:3684  d_loss:0.4189  g_loss:2.0757
# epoch:3685  d_loss:0.4393  g_loss:1.9587
# epoch:3686  d_loss:0.4557  g_loss:1.9311
# epoch:3687  d_loss:0.4826  g_loss:1.8714
# epoch:3688  d_loss:0.4390  g_loss:1.6961
# epoch:3689  d_loss:0.6969  g_loss:1.7964
# epoch:3690  d_loss:0.4367  g_loss:2.1975
# epoch:3691  d_loss:0.4997  g_loss:1.9027
# epoch:3692  d_loss:0.3607  g_loss:1.8341
# epoch:3693  d_loss:0.3923  g_loss:2.1538
# epoch:3694  d_loss:0.3532  g_loss:1.9630
# epoch:3695  d_loss:0.4296  g_loss:1.8971
# epoch:3696  d_loss:0.4343  g_loss:1.6376
# epoch:3697  d_loss:0.4790  g_loss:2.0293
# epoch:3698  d_loss:0.4554  g_loss:1.8357
# epoch:3699  d_loss:0.6520  g_loss:1.5597
# epoch:3700  d_loss:0.5180  g_loss:1.6429
# epoch:3701  d_loss:0.5477  g_loss:2.2590
# epoch:3702  d_loss:0.6491  g_loss:1.7432
# epoch:3703  d_loss:0.5451  g_loss:1.7057
# epoch:3704  d_loss:0.5239  g_loss:1.8152
# epoch:3705  d_loss:0.4540  g_loss:1.7884
# epoch:3706  d_loss:0.5945  g_loss:1.4220
# epoch:3707  d_loss:0.4495  g_loss:1.7283
# epoch:3708  d_loss:0.4690  g_loss:1.4859
# epoch:3709  d_loss:0.5785  g_loss:1.7323
# epoch:3710  d_loss:0.5528  g_loss:1.9221
# epoch:3711  d_loss:0.6211  g_loss:1.8686
# epoch:3712  d_loss:0.4182  g_loss:1.6976
# epoch:3713  d_loss:0.4776  g_loss:1.7004
# epoch:3714  d_loss:0.5486  g_loss:2.0362
# epoch:3715  d_loss:0.5070  g_loss:2.0832
# epoch:3716  d_loss:0.5050  g_loss:1.8972
# epoch:3717  d_loss:0.4303  g_loss:1.6518
# epoch:3718  d_loss:0.3583  g_loss:1.7002
# epoch:3719  d_loss:0.3293  g_loss:1.9800
# epoch:3720  d_loss:0.4477  g_loss:1.6265
# epoch:3721  d_loss:0.3898  g_loss:1.8715
# epoch:3722  d_loss:0.3321  g_loss:1.5418
# epoch:3723  d_loss:0.3144  g_loss:1.8026
# epoch:3724  d_loss:0.3237  g_loss:2.0061
# epoch:3725  d_loss:0.4162  g_loss:2.0325
# epoch:3726  d_loss:0.3573  g_loss:2.2340
# epoch:3727  d_loss:0.5350  g_loss:1.8472
# epoch:3728  d_loss:0.5426  g_loss:1.6048
# epoch:3729  d_loss:0.3542  g_loss:1.9540
# epoch:3730  d_loss:0.4517  g_loss:1.6220
# epoch:3731  d_loss:0.5250  g_loss:1.8527
# epoch:3732  d_loss:0.5289  g_loss:1.6270
# epoch:3733  d_loss:0.4487  g_loss:1.7080
# epoch:3734  d_loss:0.4388  g_loss:1.6000
# epoch:3735  d_loss:0.4675  g_loss:1.7774
# epoch:3736  d_loss:0.4317  g_loss:1.9998
# epoch:3737  d_loss:0.4428  g_loss:1.4485
# epoch:3738  d_loss:0.5645  g_loss:1.4612
# epoch:3739  d_loss:0.4734  g_loss:1.7582
# epoch:3740  d_loss:0.4791  g_loss:1.6978
# epoch:3741  d_loss:0.5413  g_loss:1.2831
# epoch:3742  d_loss:0.4604  g_loss:1.4287
# epoch:3743  d_loss:0.5613  g_loss:1.3706
# epoch:3744  d_loss:0.4901  g_loss:1.6209
# epoch:3745  d_loss:0.3593  g_loss:1.8418
# epoch:3746  d_loss:0.5320  g_loss:1.4595
# epoch:3747  d_loss:0.4792  g_loss:1.4895
# epoch:3748  d_loss:0.4104  g_loss:2.0166
# epoch:3749  d_loss:0.4770  g_loss:1.9579
# epoch:3750  d_loss:0.5390  g_loss:2.0670
# epoch:3751  d_loss:0.5681  g_loss:1.5953
# epoch:3752  d_loss:0.4547  g_loss:1.5816
# epoch:3753  d_loss:0.4266  g_loss:1.6117
# epoch:3754  d_loss:0.5070  g_loss:1.6764
# epoch:3755  d_loss:0.5788  g_loss:1.3273
# epoch:3756  d_loss:0.5140  g_loss:1.4447
# epoch:3757  d_loss:0.4580  g_loss:1.5908
# epoch:3758  d_loss:0.3797  g_loss:1.6743
# epoch:3759  d_loss:0.5179  g_loss:1.7020
# epoch:3760  d_loss:0.4396  g_loss:2.0012
# epoch:3761  d_loss:0.4577  g_loss:1.6995
# epoch:3762  d_loss:0.4568  g_loss:1.7399
# epoch:3763  d_loss:0.4861  g_loss:1.6107
# epoch:3764  d_loss:0.5050  g_loss:1.7874
# epoch:3765  d_loss:0.3738  g_loss:1.8792
# epoch:3766  d_loss:0.3590  g_loss:2.2225
# epoch:3767  d_loss:0.3900  g_loss:2.2993
# epoch:3768  d_loss:0.3667  g_loss:2.0577
# epoch:3769  d_loss:0.3179  g_loss:2.0676
# epoch:3770  d_loss:0.4269  g_loss:1.5231
# epoch:3771  d_loss:0.2327  g_loss:2.0988
# epoch:3772  d_loss:0.4157  g_loss:2.0625
# epoch:3773  d_loss:0.3458  g_loss:2.3502
# epoch:3774  d_loss:0.3299  g_loss:2.2072
# epoch:3775  d_loss:0.5201  g_loss:2.1316
# epoch:3776  d_loss:0.4750  g_loss:1.7606
# epoch:3777  d_loss:0.4243  g_loss:1.5607
# epoch:3778  d_loss:0.3459  g_loss:1.8112
# epoch:3779  d_loss:0.5352  g_loss:1.6575
# epoch:3780  d_loss:0.4250  g_loss:1.9410
# epoch:3781  d_loss:0.5113  g_loss:1.9201
# epoch:3782  d_loss:0.5188  g_loss:1.8686
# epoch:3783  d_loss:0.6535  g_loss:1.3725
# epoch:3784  d_loss:0.7241  g_loss:1.3595
# epoch:3785  d_loss:0.5264  g_loss:1.5507
# epoch:3786  d_loss:0.5227  g_loss:1.6372
# epoch:3787  d_loss:0.4865  g_loss:1.8586
# epoch:3788  d_loss:0.6086  g_loss:1.4888
# epoch:3789  d_loss:0.5980  g_loss:1.5007
# epoch:3790  d_loss:0.5725  g_loss:1.4555
# epoch:3791  d_loss:0.5189  g_loss:1.5347
# epoch:3792  d_loss:0.2983  g_loss:2.0260
# epoch:3793  d_loss:0.5576  g_loss:1.4724
# epoch:3794  d_loss:0.3950  g_loss:1.4307
# epoch:3795  d_loss:0.4708  g_loss:1.9523
# epoch:3796  d_loss:0.4980  g_loss:1.5527
# epoch:3797  d_loss:0.6391  g_loss:1.1343
# epoch:3798  d_loss:0.5155  g_loss:1.7953
# epoch:3799  d_loss:0.4840  g_loss:1.4325
# epoch:3800  d_loss:0.5592  g_loss:1.6625
# epoch:3801  d_loss:0.4297  g_loss:1.7731
# epoch:3802  d_loss:0.5227  g_loss:1.6495
# epoch:3803  d_loss:0.3922  g_loss:1.6607
# epoch:3804  d_loss:0.4470  g_loss:1.5330
# epoch:3805  d_loss:0.6021  g_loss:1.9829
# epoch:3806  d_loss:0.4915  g_loss:1.7605
# epoch:3807  d_loss:0.3797  g_loss:1.8512
# epoch:3808  d_loss:0.5400  g_loss:1.8865
# epoch:3809  d_loss:0.4460  g_loss:1.6386
# epoch:3810  d_loss:0.4214  g_loss:1.6067
# epoch:3811  d_loss:0.4448  g_loss:1.3054
# epoch:3812  d_loss:0.3621  g_loss:1.7302
# epoch:3813  d_loss:0.3737  g_loss:1.9591
# epoch:3814  d_loss:0.4726  g_loss:2.0740
# epoch:3815  d_loss:0.3533  g_loss:2.0390
# epoch:3816  d_loss:0.3758  g_loss:1.8034
# epoch:3817  d_loss:0.4258  g_loss:1.8578
# epoch:3818  d_loss:0.4843  g_loss:1.8944
# epoch:3819  d_loss:0.4561  g_loss:1.8111
# epoch:3820  d_loss:0.5157  g_loss:1.6872
# epoch:3821  d_loss:0.4064  g_loss:1.8887
# epoch:3822  d_loss:0.4210  g_loss:1.7733
# epoch:3823  d_loss:0.4159  g_loss:1.8790
# epoch:3824  d_loss:0.5536  g_loss:1.6206
# epoch:3825  d_loss:0.4354  g_loss:1.6513
# epoch:3826  d_loss:0.4874  g_loss:1.8376
# epoch:3827  d_loss:0.4566  g_loss:1.4676
# epoch:3828  d_loss:0.4450  g_loss:1.5127
# epoch:3829  d_loss:0.5375  g_loss:2.0274
# epoch:3830  d_loss:0.3730  g_loss:1.8677
# epoch:3831  d_loss:0.5080  g_loss:1.5660
# epoch:3832  d_loss:0.4546  g_loss:1.8961
# epoch:3833  d_loss:0.3637  g_loss:1.9637
# epoch:3834  d_loss:0.5010  g_loss:1.7413
# epoch:3835  d_loss:0.4764  g_loss:2.0532
# epoch:3836  d_loss:0.4100  g_loss:1.8128
# epoch:3837  d_loss:0.6922  g_loss:1.5846
# epoch:3838  d_loss:0.4719  g_loss:1.6582
# epoch:3839  d_loss:0.6239  g_loss:1.2510
# epoch:3840  d_loss:0.3675  g_loss:1.8519
# epoch:3841  d_loss:0.4547  g_loss:1.9193
# epoch:3842  d_loss:0.5520  g_loss:1.6236
# epoch:3843  d_loss:0.4491  g_loss:1.9696
# epoch:3844  d_loss:0.4951  g_loss:1.4567
# epoch:3845  d_loss:0.4328  g_loss:1.6526
# epoch:3846  d_loss:0.5224  g_loss:1.5778
# epoch:3847  d_loss:0.5975  g_loss:2.0416
# epoch:3848  d_loss:0.4141  g_loss:1.6631
# epoch:3849  d_loss:0.4209  g_loss:2.2342
# epoch:3850  d_loss:0.5133  g_loss:1.9362
# epoch:3851  d_loss:0.4542  g_loss:2.5212
# epoch:3852  d_loss:0.4930  g_loss:1.8399
# epoch:3853  d_loss:0.3866  g_loss:1.7057
# epoch:3854  d_loss:0.5541  g_loss:1.5933
# epoch:3855  d_loss:0.4897  g_loss:1.4213
# epoch:3856  d_loss:0.5137  g_loss:1.5098
# epoch:3857  d_loss:0.4623  g_loss:1.9457
# epoch:3858  d_loss:0.5398  g_loss:1.7108
# epoch:3859  d_loss:0.5154  g_loss:1.6155
# epoch:3860  d_loss:0.5655  g_loss:1.7210
# epoch:3861  d_loss:0.3958  g_loss:1.5019
# epoch:3862  d_loss:0.5180  g_loss:1.7216
# epoch:3863  d_loss:0.5950  g_loss:1.7894
# epoch:3864  d_loss:0.4071  g_loss:1.6781
# epoch:3865  d_loss:0.4758  g_loss:1.3947
# epoch:3866  d_loss:0.4365  g_loss:1.5164
# epoch:3867  d_loss:0.4163  g_loss:1.6197
# epoch:3868  d_loss:0.5682  g_loss:1.7563
# epoch:3869  d_loss:0.4554  g_loss:1.7613
# epoch:3870  d_loss:0.4073  g_loss:1.8258
# epoch:3871  d_loss:0.4629  g_loss:2.0126
# epoch:3872  d_loss:0.5869  g_loss:1.4236
# epoch:3873  d_loss:0.4458  g_loss:1.5902
# epoch:3874  d_loss:0.5155  g_loss:1.4753
# epoch:3875  d_loss:0.6548  g_loss:1.5108
# epoch:3876  d_loss:0.4745  g_loss:1.4976
# epoch:3877  d_loss:0.4264  g_loss:1.6500
# epoch:3878  d_loss:0.5398  g_loss:1.4944
# epoch:3879  d_loss:0.3820  g_loss:1.8226
# epoch:3880  d_loss:0.3524  g_loss:2.0011
# epoch:3881  d_loss:0.4930  g_loss:1.6266
# epoch:3882  d_loss:0.5124  g_loss:1.5189
# epoch:3883  d_loss:0.4104  g_loss:1.6670
# epoch:3884  d_loss:0.5206  g_loss:1.8053
# epoch:3885  d_loss:0.6265  g_loss:1.4311
# epoch:3886  d_loss:0.4704  g_loss:1.4589
# epoch:3887  d_loss:0.5600  g_loss:1.5829
# epoch:3888  d_loss:0.3769  g_loss:1.7379
# epoch:3889  d_loss:0.3478  g_loss:1.9101
# epoch:3890  d_loss:0.4434  g_loss:2.1960
# epoch:3891  d_loss:0.4696  g_loss:1.9521
# epoch:3892  d_loss:0.4438  g_loss:1.8839
# epoch:3893  d_loss:0.5715  g_loss:1.3119
# epoch:3894  d_loss:0.4859  g_loss:1.8230
# epoch:3895  d_loss:0.3944  g_loss:1.3501
# epoch:3896  d_loss:0.5603  g_loss:1.7486
# epoch:3897  d_loss:0.4343  g_loss:1.7809
# epoch:3898  d_loss:0.4971  g_loss:1.8872
# epoch:3899  d_loss:0.3806  g_loss:2.1594
# epoch:3900  d_loss:0.5743  g_loss:1.4593
# epoch:3901  d_loss:0.3336  g_loss:1.9839
# epoch:3902  d_loss:0.4887  g_loss:1.3645
# epoch:3903  d_loss:0.4340  g_loss:1.4636
# epoch:3904  d_loss:0.4574  g_loss:1.4785
# epoch:3905  d_loss:0.6084  g_loss:1.3064
# epoch:3906  d_loss:0.5873  g_loss:2.0122
# epoch:3907  d_loss:0.5059  g_loss:1.7591
# epoch:3908  d_loss:0.5343  g_loss:1.5237
# epoch:3909  d_loss:0.5777  g_loss:1.5203
# epoch:3910  d_loss:0.5039  g_loss:1.5642
# epoch:3911  d_loss:0.4634  g_loss:1.7009
# epoch:3912  d_loss:0.5242  g_loss:1.4087
# epoch:3913  d_loss:0.4826  g_loss:1.7850
# epoch:3914  d_loss:0.5296  g_loss:1.7360
# epoch:3915  d_loss:0.5003  g_loss:1.9732
# epoch:3916  d_loss:0.5066  g_loss:1.8684
# epoch:3917  d_loss:0.5016  g_loss:1.3589
# epoch:3918  d_loss:0.6361  g_loss:1.0711
# epoch:3919  d_loss:0.6105  g_loss:1.2685
# epoch:3920  d_loss:0.5205  g_loss:1.5732
# epoch:3921  d_loss:0.4676  g_loss:1.5556
# epoch:3922  d_loss:0.3821  g_loss:1.9471
# epoch:3923  d_loss:0.5235  g_loss:1.4427
# epoch:3924  d_loss:0.5366  g_loss:1.6857
# epoch:3925  d_loss:0.5676  g_loss:1.6425
# epoch:3926  d_loss:0.5736  g_loss:1.4199
# epoch:3927  d_loss:0.4799  g_loss:1.7437
# epoch:3928  d_loss:0.4905  g_loss:1.8186
# epoch:3929  d_loss:0.7157  g_loss:1.6471
# epoch:3930  d_loss:0.3466  g_loss:1.6388
# epoch:3931  d_loss:0.4133  g_loss:1.9193
# epoch:3932  d_loss:0.4148  g_loss:1.4716
# epoch:3933  d_loss:0.3719  g_loss:1.8339
# epoch:3934  d_loss:0.5797  g_loss:1.5329
# epoch:3935  d_loss:0.4172  g_loss:1.6771
# epoch:3936  d_loss:0.5455  g_loss:1.7033
# epoch:3937  d_loss:0.4365  g_loss:1.5001
# epoch:3938  d_loss:0.5204  g_loss:1.7921
# epoch:3939  d_loss:0.4743  g_loss:1.7106
# epoch:3940  d_loss:0.5666  g_loss:1.8114
# epoch:3941  d_loss:0.4104  g_loss:1.1398
# epoch:3942  d_loss:0.5831  g_loss:1.2059
# epoch:3943  d_loss:0.4030  g_loss:1.6367
# epoch:3944  d_loss:0.4496  g_loss:1.7793
# epoch:3945  d_loss:0.4382  g_loss:1.6268
# epoch:3946  d_loss:0.4482  g_loss:1.7122
# epoch:3947  d_loss:0.3918  g_loss:1.6486
# epoch:3948  d_loss:0.3697  g_loss:2.0182
# epoch:3949  d_loss:0.4612  g_loss:1.7377
# epoch:3950  d_loss:0.5995  g_loss:1.5573
# epoch:3951  d_loss:0.5973  g_loss:1.4136
# epoch:3952  d_loss:0.4904  g_loss:1.4801
# epoch:3953  d_loss:0.4145  g_loss:1.4679
# epoch:3954  d_loss:0.4360  g_loss:1.8186
# epoch:3955  d_loss:0.4958  g_loss:2.0694
# epoch:3956  d_loss:0.3780  g_loss:2.2122
# epoch:3957  d_loss:0.5107  g_loss:1.7805
# epoch:3958  d_loss:0.5413  g_loss:1.8564
# epoch:3959  d_loss:0.5414  g_loss:1.4671
# epoch:3960  d_loss:0.4917  g_loss:1.2069
# epoch:3961  d_loss:0.5280  g_loss:1.6399
# epoch:3962  d_loss:0.4263  g_loss:1.4697
# epoch:3963  d_loss:0.4872  g_loss:1.6636
# epoch:3964  d_loss:0.4456  g_loss:1.6037
# epoch:3965  d_loss:0.6689  g_loss:1.8175
# epoch:3966  d_loss:0.5008  g_loss:1.4693
# epoch:3967  d_loss:0.5858  g_loss:1.2409
# epoch:3968  d_loss:0.5362  g_loss:1.5467
# epoch:3969  d_loss:0.5905  g_loss:1.3145
# epoch:3970  d_loss:0.4165  g_loss:1.6395
# epoch:3971  d_loss:0.4440  g_loss:2.0421
# epoch:3972  d_loss:0.4299  g_loss:1.9303
# epoch:3973  d_loss:0.5591  g_loss:1.4177
# epoch:3974  d_loss:0.4759  g_loss:1.5525
# epoch:3975  d_loss:0.4651  g_loss:1.6928
# epoch:3976  d_loss:0.6854  g_loss:1.5889
# epoch:3977  d_loss:0.4112  g_loss:1.8575
# epoch:3978  d_loss:0.4773  g_loss:1.9012
# epoch:3979  d_loss:0.4393  g_loss:1.6856
# epoch:3980  d_loss:0.6211  g_loss:1.2381
# epoch:3981  d_loss:0.4876  g_loss:1.4397
# epoch:3982  d_loss:0.4643  g_loss:1.7283
# epoch:3983  d_loss:0.4488  g_loss:1.9999
# epoch:3984  d_loss:0.5769  g_loss:1.7256
# epoch:3985  d_loss:0.4924  g_loss:1.7255
# epoch:3986  d_loss:0.4850  g_loss:1.7039
# epoch:3987  d_loss:0.5959  g_loss:1.5701
# epoch:3988  d_loss:0.5593  g_loss:1.3648
# epoch:3989  d_loss:0.4822  g_loss:1.8893
# epoch:3990  d_loss:0.5818  g_loss:1.4797
# epoch:3991  d_loss:0.3949  g_loss:1.9232
# epoch:3992  d_loss:0.5193  g_loss:1.8787
# epoch:3993  d_loss:0.5260  g_loss:1.9745
# epoch:3994  d_loss:0.5658  g_loss:1.7230
# epoch:3995  d_loss:0.5423  g_loss:1.6341
# epoch:3996  d_loss:0.4691  g_loss:1.9031
# epoch:3997  d_loss:0.4993  g_loss:1.3578
# epoch:3998  d_loss:0.3752  g_loss:1.9627
# epoch:3999  d_loss:0.4240  g_loss:2.6069
# epoch:4000  d_loss:0.5625  g_loss:2.4027
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:93: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
